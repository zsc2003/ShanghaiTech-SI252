# %% [markdown]
# # Unit 6: Advantage Actor Critic (A2C) using Robotics Simulations with Panda-Gym 🤖
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit8/thumbnail.png"  alt="Thumbnail"/>
#
# In this notebook, you'll learn to use A2C with [Panda-Gym](https://github.com/qgallouedec/panda-gym). You're going **to train a robotic arm** (Franka Emika Panda robot) to perform a task:
#
# - `Reach`: the robot must place its end-effector at a target position.
#
# After that, you'll be able **to train in other robotics tasks**.

# %% [markdown]
# ### 🎮 Environments:
#
# - [Panda-Gym](https://github.com/qgallouedec/panda-gym)
#
# ###📚 RL-Library:
#
# - [Stable-Baselines3](https://stable-baselines3.readthedocs.io/)

# %% [markdown]
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the GitHub Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# ## Objectives of this notebook 🏆
#
# At the end of the notebook, you will:
#
# - Be able to use **Panda-Gym**, the environment library.
# - Be able to **train robots using A2C**.
# - Understand why **we need to normalize the input**.
# - Be able to **push your trained agent and the code to the Hub** with a nice video replay and an evaluation score 🔥.

# %% [markdown]
# ## This notebook is from the Deep Reinforcement Learning Course
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/deep-rl-course-illustration.jpg" alt="Deep RL Course illustration"/>
#
# In this free course, you will:
#
# - 📖 Study Deep Reinforcement Learning in **theory and practice**.
# - 🧑‍💻 Learn to **use famous Deep RL libraries** such as Stable Baselines3, RL Baselines3 Zoo, CleanRL and Sample Factory 2.0.
# - 🤖 Train **agents in unique environments**
#
# And more check 📚 the syllabus 👉 https://simoninithomas.github.io/deep-rl-course
#
# Don’t forget to **<a href="http://eepurl.com/ic5ZUD">sign up to the course</a>** (we are collecting your email to be able to **send you the links when each Unit is published and give you information about the challenges and updates).**
#
#
# The best way to keep in touch is to join our discord server to exchange with the community and with us 👉🏻 https://discord.gg/ydHrjt3WP5

# %% [markdown]
# ## Prerequisites 🏗️
# Before diving into the notebook, you need to:
#
# 🔲 📚 Study [Actor-Critic methods by reading Unit 6](https://huggingface.co/deep-rl-course/unit6/introduction) 🤗

# %% [markdown]
# # Let's train our first robots 🤖

# %% [markdown]
# To validate this hands-on for the [certification process](https://huggingface.co/deep-rl-course/en/unit0/introduction#certification-process),  you need to push your trained model to the Hub and get the following results:
#
# - `PandaReachDense-v3` get a result of >= -3.5.
#
# To find your result, go to the [leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) and find your model, **the result = mean_reward - std of reward**
#
# For more information about the certification process, check this section 👉 https://huggingface.co/deep-rl-course/en/unit0/introduction#certification-process

# %% [markdown]
# ## Set the GPU 💪
# - To **accelerate the agent's training, we'll use a GPU**. To do that, go to `Runtime > Change Runtime type`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step1.jpg" alt="GPU Step 1">

# %% [markdown]
# - `Hardware Accelerator > GPU`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step2.jpg" alt="GPU Step 2">

# %% [markdown]
# ## Create a virtual display 🔽
#
# During the notebook, we'll need to generate a replay video. To do so, with colab, **we need to have a virtual screen to be able to render the environment** (and thus record the frames).
#
# Hence the following cell will install the librairies and create and run a virtual screen 🖥

# %%
# %%capture
# run the following code in the terminal
# !sudo apt install python-opengl
# !sudo apt install ffmpeg
# !sudo apt install xvfb
# !pip3 install pyvirtualdisplay

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %% [markdown]
# ### Install dependencies 🔽
#
# The first step is to install the dependencies, we’ll install multiple ones:
# - `gymnasium`
# - `panda-gym`: Contains the robotics arm environments.
# - `stable-baselines3`: The SB3 deep reinforcement learning library.
# - `huggingface_sb3`: Additional code for Stable-baselines3 to load and upload models from the Hugging Face 🤗 Hub.
# - `huggingface_hub`: Library allowing anyone to work with the Hub repositories.
#
# ⏲ The installation can **take 10 minutes**.

# %%
# !pip install stable-baselines3[extra]
# !pip install gymnasium
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: stable-baselines3[extra] in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (2.4.1)
# Requirement already satisfied: gymnasium<1.1.0,>=0.29.1 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from stable-baselines3[extra]) (1.0.0)
# Requirement already satisfied: numpy<2.0,>=1.20 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from stable-baselines3[extra]) (1.24.4)
# Requirement already satisfied: torch>=1.13 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from stable-baselines3[extra]) (2.4.1+cu118)
# Requirement already satisfied: cloudpickle in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from stable-baselines3[extra]) (3.1.1)
# Requirement already satisfied: pandas in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from stable-baselines3[extra]) (2.0.3)
# Requirement already satisfied: matplotlib in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from stable-baselines3[extra]) (3.7.5)
# Requirement already satisfied: opencv-python in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from stable-baselines3[extra]) (4.11.0.86)
# Requirement already satisfied: pygame in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from stable-baselines3[extra]) (2.1.3)
# Collecting tensorboard>=2.9.1 (from stable-baselines3[extra])
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/bc/a2/ff5f4c299eb37c95299a76015da3f30211468e29d8d6f1d011683279baee/tensorboard-2.14.0-py3-none-any.whl (5.5 MB)
# Requirement already satisfied: psutil in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from stable-baselines3[extra]) (6.0.0)
# Requirement already satisfied: tqdm in /home/cellverse/.local/lib/python3.8/site-packages (from stable-baselines3[extra]) (4.66.1)
# Requirement already satisfied: rich in /home/cellverse/.local/lib/python3.8/site-packages (from stable-baselines3[extra]) (13.7.1)
# Requirement already satisfied: ale-py>=0.9.0 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from stable-baselines3[extra]) (0.10.1)
# Requirement already satisfied: pillow in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from stable-baselines3[extra]) (10.4.0)
# Requirement already satisfied: importlib-metadata>=4.10.0 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from ale-py>=0.9.0->stable-baselines3[extra]) (8.5.0)
# Requirement already satisfied: typing-extensions in /home/cellverse/.local/lib/python3.8/site-packages (from ale-py>=0.9.0->stable-baselines3[extra]) (4.9.0)
# Requirement already satisfied: importlib-resources in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from ale-py>=0.9.0->stable-baselines3[extra]) (6.4.5)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from gymnasium<1.1.0,>=0.29.1->stable-baselines3[extra]) (0.0.4)
# Collecting absl-py>=0.4 (from tensorboard>=2.9.1->stable-baselines3[extra])
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/87/04/9d75e1d3bb4ab8ec67ff10919476ccdee06c098bcfcf3a352da5f985171d/absl_py-2.3.0-py3-none-any.whl (135 kB)
# Collecting grpcio>=1.48.2 (from tensorboard>=2.9.1->stable-baselines3[extra])
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/2c/64/66a74c02b00e00b919c245ca9da8e5c44e8692bf3fe7f27efbc97572566c/grpcio-1.70.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 91.4 MB/s eta 0:00:00
# Collecting google-auth<3,>=1.6.3 (from tensorboard>=2.9.1->stable-baselines3[extra])
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/6a/c7/e2d82e6702e2a9e2311c138f8e1100f21d08aed0231290872b229ae57a86/google_auth-2.40.2-py2.py3-none-any.whl (216 kB)
# Collecting google-auth-oauthlib<1.1,>=0.5 (from tensorboard>=2.9.1->stable-baselines3[extra])
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/4a/07/8d9a8186e6768b55dfffeb57c719bc03770cf8a970a074616ae6f9e26a57/google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Collecting markdown>=2.6.8 (from tensorboard>=2.9.1->stable-baselines3[extra])
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/3f/08/83871f3c50fc983b88547c196d11cf8c3340e37c32d2e9d6152abe2c61f7/Markdown-3.7-py3-none-any.whl (106 kB)
# Collecting protobuf>=3.19.6 (from tensorboard>=2.9.1->stable-baselines3[extra])
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/85/e4/07c80521879c2d15f321465ac24c70efe2381378c00bf5e56a0f4fbac8cd/protobuf-5.29.5-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.32.3)
# Requirement already satisfied: setuptools>=41.0.0 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (75.3.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard>=2.9.1->stable-baselines3[extra])
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/73/c6/825dab04195756cf8ff2e12698f22513b3db2f64925bdd41671bfb33aaa5/tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
# Collecting werkzeug>=1.0.1 (from tensorboard>=2.9.1->stable-baselines3[extra])
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/6c/69/05837f91dfe42109203ffa3e488214ff86a6d68b2ed6c167da6cdc42349b/werkzeug-3.0.6-py3-none-any.whl (227 kB)
# Requirement already satisfied: wheel>=0.26 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.45.1)
# Requirement already satisfied: filelock in /home/cellverse/.local/lib/python3.8/site-packages (from torch>=1.13->stable-baselines3[extra]) (3.13.1)
# Requirement already satisfied: sympy in /home/cellverse/.local/lib/python3.8/site-packages (from torch>=1.13->stable-baselines3[extra]) (1.12)
# Requirement already satisfied: networkx in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from torch>=1.13->stable-baselines3[extra]) (3.0)
# Requirement already satisfied: jinja2 in /home/cellverse/.local/lib/python3.8/site-packages (from torch>=1.13->stable-baselines3[extra]) (3.1.3)
# Requirement already satisfied: fsspec in /home/cellverse/.local/lib/python3.8/site-packages (from torch>=1.13->stable-baselines3[extra]) (2023.12.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.8.89 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from torch>=1.13->stable-baselines3[extra]) (11.8.89)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.8.89 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from torch>=1.13->stable-baselines3[extra]) (11.8.89)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.8.87 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from torch>=1.13->stable-baselines3[extra]) (11.8.87)
# Requirement already satisfied: nvidia-cudnn-cu11==9.1.0.70 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from torch>=1.13->stable-baselines3[extra]) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu11==11.11.3.6 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from torch>=1.13->stable-baselines3[extra]) (11.11.3.6)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from torch>=1.13->stable-baselines3[extra]) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.3.0.86 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from torch>=1.13->stable-baselines3[extra]) (10.3.0.86)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.1.48 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from torch>=1.13->stable-baselines3[extra]) (11.4.1.48)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.5.86 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from torch>=1.13->stable-baselines3[extra]) (11.7.5.86)
# Requirement already satisfied: nvidia-nccl-cu11==2.20.5 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from torch>=1.13->stable-baselines3[extra]) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu11==11.8.86 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from torch>=1.13->stable-baselines3[extra]) (11.8.86)
# Requirement already satisfied: triton==3.0.0 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from torch>=1.13->stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from matplotlib->stable-baselines3[extra]) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from matplotlib->stable-baselines3[extra]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from matplotlib->stable-baselines3[extra]) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from matplotlib->stable-baselines3[extra]) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/cellverse/.local/lib/python3.8/site-packages (from matplotlib->stable-baselines3[extra]) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from matplotlib->stable-baselines3[extra]) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from matplotlib->stable-baselines3[extra]) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from pandas->stable-baselines3[extra]) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from pandas->stable-baselines3[extra]) (2025.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/cellverse/.local/lib/python3.8/site-packages (from rich->stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/cellverse/.local/lib/python3.8/site-packages (from rich->stable-baselines3[extra]) (2.18.0)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra])
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/72/76/20fa66124dbe6be5cafeb312ece67de6b61dd91a0247d1ea13db4ebb33c2/cachetools-5.5.2-py3-none-any.whl (10 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra])
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/47/8d/d529b5d697919ba8c11ad626e835d4039be708a35b0d22de83a269a6682c/pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra])
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/64/8d/0133e4eb4beed9e425d9a98ed6e081a55d195481b7632472be1af08d2f6b/rsa-4.9.1-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra])
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/3b/5d/63d4ae3b9daea098d5d6f5da83984853c1bbacd5dc826764b249fe119d24/requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: zipp>=3.20 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from importlib-metadata>=4.10.0->ale-py>=0.9.0->stable-baselines3[extra]) (3.21.0)
# Requirement already satisfied: mdurl~=0.1 in /home/cellverse/.local/lib/python3.8/site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: six>=1.5 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard>=2.9.1->stable-baselines3[extra]) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard>=2.9.1->stable-baselines3[extra]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard>=2.9.1->stable-baselines3[extra]) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard>=2.9.1->stable-baselines3[extra]) (2025.4.26)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/cellverse/.local/lib/python3.8/site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /home/cellverse/.local/lib/python3.8/site-packages (from sympy->torch>=1.13->stable-baselines3[extra]) (1.3.0)
# Collecting pyasn1<0.7.0,>=0.6.1 (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra])
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/c8/f1/d6a797abb14f6283c0ddff96bbdd46937f64122b8c925cab503dd37f8214/pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra])
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/7e/80/cab10959dc1faead58dc8384a781dfbf93cb4d33d50988f7a69f1b7c9bbe/oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Installing collected packages: werkzeug, tensorboard-data-server, pyasn1, protobuf, oauthlib, grpcio, cachetools, absl-py, rsa, requests-oauthlib, pyasn1-modules, markdown, google-auth, google-auth-oauthlib, tensorboard
# Successfully installed absl-py-2.3.0 cachetools-5.5.2 google-auth-2.40.2 google-auth-oauthlib-1.0.0 grpcio-1.70.0 markdown-3.7 oauthlib-3.2.2 protobuf-5.29.5 pyasn1-0.6.1 pyasn1-modules-0.4.2 requests-oauthlib-2.0.0 rsa-4.9.1 tensorboard-2.14.0 tensorboard-data-server-0.7.2 werkzeug-3.0.6
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: gymnasium in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (1.0.0)
# Requirement already satisfied: numpy>=1.21.0 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from gymnasium) (1.24.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from gymnasium) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/cellverse/.local/lib/python3.8/site-packages (from gymnasium) (4.9.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from gymnasium) (8.5.0)
# Requirement already satisfied: zipp>=3.20 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from importlib-metadata>=4.8.0->gymnasium) (3.21.0)

# %%
# !pip install huggingface_sb3
# !pip install huggingface_hub
# !pip install panda_gym
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: huggingface_sb3 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (3.0)
# Requirement already satisfied: huggingface-hub~=0.8 in /home/cellverse/.local/lib/python3.8/site-packages (from huggingface_sb3) (0.20.2)
# Requirement already satisfied: pyyaml~=6.0 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from huggingface_sb3) (6.0)
# Requirement already satisfied: wasabi in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from huggingface_sb3) (1.1.3)
# Requirement already satisfied: numpy in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from huggingface_sb3) (1.24.4)
# Requirement already satisfied: cloudpickle>=1.6 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from huggingface_sb3) (3.1.1)
# Requirement already satisfied: filelock in /home/cellverse/.local/lib/python3.8/site-packages (from huggingface-hub~=0.8->huggingface_sb3) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/cellverse/.local/lib/python3.8/site-packages (from huggingface-hub~=0.8->huggingface_sb3) (2023.12.2)
# Requirement already satisfied: requests in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from huggingface-hub~=0.8->huggingface_sb3) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /home/cellverse/.local/lib/python3.8/site-packages (from huggingface-hub~=0.8->huggingface_sb3) (4.66.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/cellverse/.local/lib/python3.8/site-packages (from huggingface-hub~=0.8->huggingface_sb3) (4.9.0)
# Requirement already satisfied: packaging>=20.9 in /home/cellverse/.local/lib/python3.8/site-packages (from huggingface-hub~=0.8->huggingface_sb3) (23.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (2025.4.26)
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: huggingface_hub in /home/cellverse/.local/lib/python3.8/site-packages (0.20.2)
# Requirement already satisfied: filelock in /home/cellverse/.local/lib/python3.8/site-packages (from huggingface_hub) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/cellverse/.local/lib/python3.8/site-packages (from huggingface_hub) (2023.12.2)
# Requirement already satisfied: requests in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from huggingface_hub) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /home/cellverse/.local/lib/python3.8/site-packages (from huggingface_hub) (4.66.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from huggingface_hub) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/cellverse/.local/lib/python3.8/site-packages (from huggingface_hub) (4.9.0)
# Requirement already satisfied: packaging>=20.9 in /home/cellverse/.local/lib/python3.8/site-packages (from huggingface_hub) (23.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from requests->huggingface_hub) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from requests->huggingface_hub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from requests->huggingface_hub) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from requests->huggingface_hub) (2025.4.26)
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting panda_gym
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/1a/aa/4eb790df24fc475e8c31c960c83a4aec2991e06293eed1e06c0eab9145bb/panda_gym-3.0.7-py3-none-any.whl (23 kB)
# Requirement already satisfied: gymnasium>=0.26 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from panda_gym) (1.0.0)
# Collecting pybullet (from panda_gym)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/66/e9/4d26f9efaf9b95609ee4f8357a3a306c3c6a40aea7c3ca5f28864615b1c7/pybullet-3.2.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (103.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 MB 39.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: numpy in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from panda_gym) (1.24.4)
# Collecting scipy (from panda_gym)
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/69/f0/fb07a9548e48b687b8bf2fa81d71aba9cfc548d365046ca1c791e24db99d/scipy-1.10.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.5 MB)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from gymnasium>=0.26->panda_gym) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/cellverse/.local/lib/python3.8/site-packages (from gymnasium>=0.26->panda_gym) (4.9.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from gymnasium>=0.26->panda_gym) (0.0.4)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from gymnasium>=0.26->panda_gym) (8.5.0)
# Requirement already satisfied: zipp>=3.20 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from importlib-metadata>=4.8.0->gymnasium>=0.26->panda_gym) (3.21.0)
# Installing collected packages: pybullet, scipy, panda_gym
# Successfully installed panda_gym-3.0.7 pybullet-3.2.7 scipy-1.10.1

# %% [markdown]
# ## Import the packages 📦

# %%
import os

import gymnasium as gym
import panda_gym

from huggingface_sb3 import load_from_hub, package_to_hub

from stable_baselines3 import A2C
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from stable_baselines3.common.env_util import make_vec_env

from huggingface_hub import notebook_login

# %% [markdown]
# ## PandaReachDense-v3 🦾
#
# The agent we're going to train is a robotic arm that needs to do controls (moving the arm and using the end-effector).
#
# In robotics, the *end-effector* is the device at the end of a robotic arm designed to interact with the environment.
#
# In `PandaReach`, the robot must place its end-effector at a target position (green ball).
#
# We're going to use the dense version of this environment. It means we'll get a *dense reward function* that **will provide a reward at each timestep** (the closer the agent is to completing the task, the higher the reward). Contrary to a *sparse reward function* where the environment **return a reward if and only if the task is completed**.
#
# Also, we're going to use the *End-effector displacement control*, it means the **action corresponds to the displacement of the end-effector**. We don't control the individual motion of each joint (joint control).
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit8/robotics.jpg"  alt="Robotics"/>
#
#
# This way **the training will be easier**.

# %% [markdown]
# ### Create the environment
#
# #### The environment 🎮
#
# In `PandaReachDense-v3` the robotic arm must place its end-effector at a target position (green ball).

# %%
env_id = "PandaReachDense-v3"

# Create the env
env = gym.make(env_id)

# Get the state space and action space
s_size = env.observation_space.shape
a_size = env.action_space
# Out:
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# pybullet build time: Jan 29 2025 23:19:57

# %%
print("_____OBSERVATION SPACE_____ \n")
print("The State Space is: ", s_size)
print("Sample observation", env.observation_space.sample()) # Get a random observation
# Out:
# _____OBSERVATION SPACE_____
#
# The State Space is:  None
# Sample observation {'achieved_goal': array([-1.2751015,  7.311272 , -0.6041822], dtype=float32), 'desired_goal': array([5.3130026, 8.087073 , 0.8753509], dtype=float32), 'observation': array([-0.30655167, -1.9787016 ,  8.218347  , -8.101035  , -9.932389  ,
#        -5.597065  ], dtype=float32)}

# %% [markdown]
# The observation space **is a dictionary with 3 different elements**:
# - `achieved_goal`: (x,y,z) the current position of the end-effector.
# - `desired_goal`: (x,y,z) the target position for the end-effector.
# - `observation`: position (x,y,z) and velocity of the end-effector (vx, vy, vz).
#
# Given it's a dictionary as observation, **we will need to use a MultiInputPolicy policy instead of MlpPolicy**.

# %%
print("\n _____ACTION SPACE_____ \n")
print("The Action Space is: ", a_size)
print("Action Space Sample", env.action_space.sample()) # Take a random action
# Out:
#  _____ACTION SPACE_____
#
# The Action Space is:  Box(-1.0, 1.0, (3,), float32)
# Action Space Sample [-0.983713   -0.45568022 -0.69503725]

# %% [markdown]
# The action space is a vector with 3 values:
# - Control x, y, z movement

# %% [markdown]
# ### Normalize observation and rewards

# %% [markdown]
# A good practice in reinforcement learning is to [normalize input features](https://stable-baselines3.readthedocs.io/en/master/guide/rl_tips.html).
#
# For that purpose, there is a wrapper that will compute a running average and standard deviation of input features.
#
# We also normalize rewards with this same wrapper by adding `norm_reward = True`
#
# [You should check the documentation to fill this cell](https://stable-baselines3.readthedocs.io/en/master/guide/vec_envs.html#vecnormalize)

# %%
env = make_vec_env(env_id, n_envs=4)

env = VecNormalize(env, norm_obs=True, norm_reward=True, clip_obs=10.)
# Out:
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886

# %% [markdown]
# ### Create the A2C Model 🤖
#
# For more information about A2C implementation with StableBaselines3 check: https://stable-baselines3.readthedocs.io/en/master/modules/a2c.html#notes
#
# To find the best parameters I checked the [official trained agents by Stable-Baselines3 team](https://huggingface.co/sb3).

# %%
model = A2C(policy = "MultiInputPolicy",
            env = env,
            verbose=1)
# Out:
# Using cuda device

# %% [markdown]
# ### Train the A2C agent 🏃
# - Let's train our agent for 1,000,000 timesteps, don't forget to use GPU on Colab. It will take approximately ~25-40min

# %%
model.learn(1_000_000)
# Out:
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 45.1     |
# |    ep_rew_mean        | -10.3    |
# |    success_rate       | 0.143    |
# | time/                 |          |
# |    fps                | 840      |
# |    iterations         | 100      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -4.27    |
# |    explained_variance | 0.92     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -1.07    |
# |    std                | 1        |
# |    value_loss         | 0.0906   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 43.3     |
# |    ep_rew_mean        | -10.2    |
# |    success_rate       | 0.202    |
# | time/                 |          |
# |    fps                | 877      |
# |    iterations         | 200      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -4.28    |
# |    explained_variance | 0.849    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | -1.2     |
# |    std                | 1.01     |
# |    value_loss         | 0.2      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 41.1     |
# |    ep_rew_mean        | -11      |
# |    success_rate       | 0.23     |
# | time/                 |          |
# |    fps                | 890      |
# |    iterations         | 300      |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -4.29    |
# |    explained_variance | 0.133    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | 0.869    |
# |    std                | 1.01     |
# |    value_loss         | 0.117    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 40       |
# |    ep_rew_mean        | -10.9    |
# |    success_rate       | 0.24     |
# | time/                 |          |
# |    fps                | 896      |
# |    iterations         | 400      |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -4.29    |
# |    explained_variance | 0.972    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 0.34     |
# |    std                | 1.01     |
# |    value_loss         | 0.0686   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 40.8     |
# |    ep_rew_mean        | -10.1    |
# |    success_rate       | 0.24     |
# | time/                 |          |
# |    fps                | 896      |
# |    iterations         | 500      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -4.31    |
# |    explained_variance | 0.947    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 1.06     |
# |    std                | 1.02     |
# |    value_loss         | 0.143    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 42.5     |
# |    ep_rew_mean        | -10.2    |
# |    success_rate       | 0.19     |
# | time/                 |          |
# |    fps                | 899      |
# |    iterations         | 600      |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -4.33    |
# |    explained_variance | 0.988    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 0.416    |
# |    std                | 1.02     |
# |    value_loss         | 0.0523   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 41.8     |
# |    ep_rew_mean        | -9.72    |
# |    success_rate       | 0.2      |
# | time/                 |          |
# |    fps                | 900      |
# |    iterations         | 700      |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -4.33    |
# |    explained_variance | 0.986    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 0.369    |
# |    std                | 1.02     |
# |    value_loss         | 0.0362   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 40.8     |
# |    ep_rew_mean        | -10.1    |
# |    success_rate       | 0.22     |
# | time/                 |          |
# |    fps                | 898      |
# |    iterations         | 800      |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -4.33    |
# |    explained_variance | 0.948    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | -0.974   |
# |    std                | 1.02     |
# |    value_loss         | 0.107    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 43.4     |
# |    ep_rew_mean        | -12.5    |
# |    success_rate       | 0.15     |
# | time/                 |          |
# |    fps                | 897      |
# |    iterations         | 900      |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -4.35    |
# |    explained_variance | 0.928    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 1.62     |
# |    std                | 1.03     |
# |    value_loss         | 0.243    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 46.1     |
# |    ep_rew_mean        | -13.2    |
# |    success_rate       | 0.09     |
# | time/                 |          |
# |    fps                | 896      |
# |    iterations         | 1000     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -4.36    |
# |    explained_variance | 0.975    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | -0.814   |
# |    std                | 1.03     |
# |    value_loss         | 0.0611   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 46.2     |
# |    ep_rew_mean        | -11.4    |
# |    success_rate       | 0.09     |
# | time/                 |          |
# |    fps                | 898      |
# |    iterations         | 1100     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -4.35    |
# |    explained_variance | 0.95     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 0.211    |
# |    std                | 1.03     |
# |    value_loss         | 0.0105   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 46.1     |
# |    ep_rew_mean        | -11.6    |
# |    success_rate       | 0.09     |
# | time/                 |          |
# |    fps                | 900      |
# |    iterations         | 1200     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -4.38    |
# |    explained_variance | 0.988    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 0.655    |
# |    std                | 1.04     |
# |    value_loss         | 0.0432   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 44.9     |
# |    ep_rew_mean        | -11.5    |
# |    success_rate       | 0.11     |
# | time/                 |          |
# |    fps                | 902      |
# |    iterations         | 1300     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -4.37    |
# |    explained_variance | 0.988    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | -0.31    |
# |    std                | 1.04     |
# |    value_loss         | 0.0261   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 44.3     |
# |    ep_rew_mean        | -11.3    |
# |    success_rate       | 0.14     |
# | time/                 |          |
# |    fps                | 904      |
# |    iterations         | 1400     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -4.4     |
# |    explained_variance | 0.993    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | -0.825   |
# |    std                | 1.05     |
# |    value_loss         | 0.0723   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 44.8     |
# |    ep_rew_mean        | -11.4    |
# |    success_rate       | 0.13     |
# | time/                 |          |
# |    fps                | 905      |
# |    iterations         | 1500     |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -4.43    |
# |    explained_variance | 0.934    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | -0.277   |
# |    std                | 1.06     |
# |    value_loss         | 0.0159   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 43.4     |
# |    ep_rew_mean        | -10.9    |
# |    success_rate       | 0.14     |
# | time/                 |          |
# |    fps                | 907      |
# |    iterations         | 1600     |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -4.46    |
# |    explained_variance | 0.956    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | 0.0024   |
# |    std                | 1.07     |
# |    value_loss         | 0.0169   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 43.4     |
# |    ep_rew_mean        | -11      |
# |    success_rate       | 0.14     |
# | time/                 |          |
# |    fps                | 909      |
# |    iterations         | 1700     |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -4.46    |
# |    explained_variance | 0.991    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | 0.328    |
# |    std                | 1.07     |
# |    value_loss         | 0.0111   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 41.4     |
# |    ep_rew_mean        | -10.6    |
# |    success_rate       | 0.19     |
# | time/                 |          |
# |    fps                | 910      |
# |    iterations         | 1800     |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -4.49    |
# |    explained_variance | 0.575    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 2.77     |
# |    std                | 1.08     |
# |    value_loss         | 3.88     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 40.5     |
# |    ep_rew_mean        | -9.97    |
# |    success_rate       | 0.21     |
# | time/                 |          |
# |    fps                | 910      |
# |    iterations         | 1900     |
# |    time_elapsed       | 41       |
# |    total_timesteps    | 38000    |
# | train/                |          |
# |    entropy_loss       | -4.48    |
# |    explained_variance | 0.992    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | 0.167    |
# |    std                | 1.08     |
# |    value_loss         | 0.0106   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 41.2     |
# |    ep_rew_mean        | -10.4    |
# |    success_rate       | 0.19     |
# | time/                 |          |
# |    fps                | 912      |
# |    iterations         | 2000     |
# |    time_elapsed       | 43       |
# |    total_timesteps    | 40000    |
# | train/                |          |
# |    entropy_loss       | -4.45    |
# |    explained_variance | 0.993    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.262    |
# |    std                | 1.07     |
# |    value_loss         | 0.0205   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 41.7     |
# |    ep_rew_mean        | -10.5    |
# |    success_rate       | 0.18     |
# | time/                 |          |
# |    fps                | 912      |
# |    iterations         | 2100     |
# |    time_elapsed       | 46       |
# |    total_timesteps    | 42000    |
# | train/                |          |
# |    entropy_loss       | -4.44    |
# |    explained_variance | 0.996    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | 0.217    |
# |    std                | 1.06     |
# |    value_loss         | 0.0141   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 40.8     |
# |    ep_rew_mean        | -9.5     |
# |    success_rate       | 0.2      |
# | time/                 |          |
# |    fps                | 913      |
# |    iterations         | 2200     |
# |    time_elapsed       | 48       |
# |    total_timesteps    | 44000    |
# | train/                |          |
# |    entropy_loss       | -4.44    |
# |    explained_variance | 0.985    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | 0.699    |
# |    std                | 1.07     |
# |    value_loss         | 0.0983   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 39.2     |
# |    ep_rew_mean        | -8.6     |
# |    success_rate       | 0.25     |
# | time/                 |          |
# |    fps                | 913      |
# |    iterations         | 2300     |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 46000    |
# | train/                |          |
# |    entropy_loss       | -4.47    |
# |    explained_variance | 0.994    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | 0.45     |
# |    std                | 1.07     |
# |    value_loss         | 0.0282   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 40.2     |
# |    ep_rew_mean        | -8.82    |
# |    success_rate       | 0.23     |
# | time/                 |          |
# |    fps                | 914      |
# |    iterations         | 2400     |
# |    time_elapsed       | 52       |
# |    total_timesteps    | 48000    |
# | train/                |          |
# |    entropy_loss       | -4.47    |
# |    explained_variance | 0.621    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | 4.2      |
# |    std                | 1.07     |
# |    value_loss         | 3.67     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 43.4     |
# |    ep_rew_mean        | -9.88    |
# |    success_rate       | 0.17     |
# | time/                 |          |
# |    fps                | 914      |
# |    iterations         | 2500     |
# |    time_elapsed       | 54       |
# |    total_timesteps    | 50000    |
# | train/                |          |
# |    entropy_loss       | -4.45    |
# |    explained_variance | 0.997    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | -0.139   |
# |    std                | 1.07     |
# |    value_loss         | 0.00598  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 41.2     |
# |    ep_rew_mean        | -8.96    |
# |    success_rate       | 0.23     |
# | time/                 |          |
# |    fps                | 914      |
# |    iterations         | 2600     |
# |    time_elapsed       | 56       |
# |    total_timesteps    | 52000    |
# | train/                |          |
# |    entropy_loss       | -4.45    |
# |    explained_variance | 0.711    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | 3.1      |
# |    std                | 1.07     |
# |    value_loss         | 2.9      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 33       |
# |    ep_rew_mean        | -5.83    |
# |    success_rate       | 0.48     |
# | time/                 |          |
# |    fps                | 914      |
# |    iterations         | 2700     |
# |    time_elapsed       | 59       |
# |    total_timesteps    | 54000    |
# | train/                |          |
# |    entropy_loss       | -4.44    |
# |    explained_variance | 0.945    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | -0.158   |
# |    std                | 1.07     |
# |    value_loss         | 0.0324   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 29.5     |
# |    ep_rew_mean        | -4.62    |
# |    success_rate       | 0.68     |
# | time/                 |          |
# |    fps                | 916      |
# |    iterations         | 2800     |
# |    time_elapsed       | 61       |
# |    total_timesteps    | 56000    |
# | train/                |          |
# |    entropy_loss       | -4.4     |
# |    explained_variance | 0.961    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | -0.513   |
# |    std                | 1.05     |
# |    value_loss         | 0.0342   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 29.1     |
# |    ep_rew_mean        | -3.97    |
# |    success_rate       | 0.74     |
# | time/                 |          |
# |    fps                | 917      |
# |    iterations         | 2900     |
# |    time_elapsed       | 63       |
# |    total_timesteps    | 58000    |
# | train/                |          |
# |    entropy_loss       | -4.38    |
# |    explained_variance | 0.991    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | -0.245   |
# |    std                | 1.04     |
# |    value_loss         | 0.0137   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 16.8     |
# |    ep_rew_mean        | -2.03    |
# |    success_rate       | 0.96     |
# | time/                 |          |
# |    fps                | 917      |
# |    iterations         | 3000     |
# |    time_elapsed       | 65       |
# |    total_timesteps    | 60000    |
# | train/                |          |
# |    entropy_loss       | -4.35    |
# |    explained_variance | 0.966    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | -0.181   |
# |    std                | 1.03     |
# |    value_loss         | 0.0123   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 11       |
# |    ep_rew_mean        | -1.2     |
# |    success_rate       | 0.99     |
# | time/                 |          |
# |    fps                | 919      |
# |    iterations         | 3100     |
# |    time_elapsed       | 67       |
# |    total_timesteps    | 62000    |
# | train/                |          |
# |    entropy_loss       | -4.33    |
# |    explained_variance | 0.302    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | 0.246    |
# |    std                | 1.03     |
# |    value_loss         | 0.0557   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.12     |
# |    ep_rew_mean        | -0.652   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 920      |
# |    iterations         | 3200     |
# |    time_elapsed       | 69       |
# |    total_timesteps    | 64000    |
# | train/                |          |
# |    entropy_loss       | -4.28    |
# |    explained_variance | 0.324    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | -0.368   |
# |    std                | 1.01     |
# |    value_loss         | 0.0161   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.47     |
# |    ep_rew_mean        | -0.458   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 921      |
# |    iterations         | 3300     |
# |    time_elapsed       | 71       |
# |    total_timesteps    | 66000    |
# | train/                |          |
# |    entropy_loss       | -4.24    |
# |    explained_variance | -0.507   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | -0.076   |
# |    std                | 0.995    |
# |    value_loss         | 0.00513  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.66     |
# |    ep_rew_mean        | -0.394   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 922      |
# |    iterations         | 3400     |
# |    time_elapsed       | 73       |
# |    total_timesteps    | 68000    |
# | train/                |          |
# |    entropy_loss       | -4.19    |
# |    explained_variance | -1.21    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | -0.0584  |
# |    std                | 0.98     |
# |    value_loss         | 0.00448  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.01     |
# |    ep_rew_mean        | -0.327   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 923      |
# |    iterations         | 3500     |
# |    time_elapsed       | 75       |
# |    total_timesteps    | 70000    |
# | train/                |          |
# |    entropy_loss       | -4.16    |
# |    explained_variance | -1.15    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | 0.0537   |
# |    std                | 0.968    |
# |    value_loss         | 0.00248  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.89     |
# |    ep_rew_mean        | -0.315   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 924      |
# |    iterations         | 3600     |
# |    time_elapsed       | 77       |
# |    total_timesteps    | 72000    |
# | train/                |          |
# |    entropy_loss       | -4.11    |
# |    explained_variance | -0.653   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | 0.0401   |
# |    std                | 0.954    |
# |    value_loss         | 0.00149  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.53     |
# |    ep_rew_mean        | -0.284   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 925      |
# |    iterations         | 3700     |
# |    time_elapsed       | 79       |
# |    total_timesteps    | 74000    |
# | train/                |          |
# |    entropy_loss       | -4.06    |
# |    explained_variance | -1.62    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | -0.204   |
# |    std                | 0.938    |
# |    value_loss         | 0.00498  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.3      |
# |    ep_rew_mean        | -0.265   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 926      |
# |    iterations         | 3800     |
# |    time_elapsed       | 82       |
# |    total_timesteps    | 76000    |
# | train/                |          |
# |    entropy_loss       | -4.03    |
# |    explained_variance | -0.466   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | -0.283   |
# |    std                | 0.925    |
# |    value_loss         | 0.00465  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.29     |
# |    ep_rew_mean        | -0.265   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 927      |
# |    iterations         | 3900     |
# |    time_elapsed       | 84       |
# |    total_timesteps    | 78000    |
# | train/                |          |
# |    entropy_loss       | -4       |
# |    explained_variance | 0.422    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | 0.0465   |
# |    std                | 0.917    |
# |    value_loss         | 0.000957 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.2      |
# |    ep_rew_mean        | -0.249   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 927      |
# |    iterations         | 4000     |
# |    time_elapsed       | 86       |
# |    total_timesteps    | 80000    |
# | train/                |          |
# |    entropy_loss       | -3.96    |
# |    explained_variance | -0.16    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.158    |
# |    std                | 0.906    |
# |    value_loss         | 0.00336  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 3.19      |
# |    ep_rew_mean        | -0.253    |
# |    success_rate       | 1         |
# | time/                 |           |
# |    fps                | 928       |
# |    iterations         | 4100      |
# |    time_elapsed       | 88        |
# |    total_timesteps    | 82000     |
# | train/                |           |
# |    entropy_loss       | -3.92     |
# |    explained_variance | -0.0876   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4099      |
# |    policy_loss        | -0.000397 |
# |    std                | 0.894     |
# |    value_loss         | 0.000815  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.38     |
# |    ep_rew_mean        | -0.27    |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 929      |
# |    iterations         | 4200     |
# |    time_elapsed       | 90       |
# |    total_timesteps    | 84000    |
# | train/                |          |
# |    entropy_loss       | -3.89    |
# |    explained_variance | 0.64     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | -0.0249  |
# |    std                | 0.886    |
# |    value_loss         | 0.00247  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.17     |
# |    ep_rew_mean        | -0.25    |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 930      |
# |    iterations         | 4300     |
# |    time_elapsed       | 92       |
# |    total_timesteps    | 86000    |
# | train/                |          |
# |    entropy_loss       | -3.85    |
# |    explained_variance | 0.664    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | -0.0146  |
# |    std                | 0.873    |
# |    value_loss         | 0.00103  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.17     |
# |    ep_rew_mean        | -0.249   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 930      |
# |    iterations         | 4400     |
# |    time_elapsed       | 94       |
# |    total_timesteps    | 88000    |
# | train/                |          |
# |    entropy_loss       | -3.83    |
# |    explained_variance | 0.148    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | 0.109    |
# |    std                | 0.867    |
# |    value_loss         | 0.00147  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.06     |
# |    ep_rew_mean        | -0.254   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 931      |
# |    iterations         | 4500     |
# |    time_elapsed       | 96       |
# |    total_timesteps    | 90000    |
# | train/                |          |
# |    entropy_loss       | -3.79    |
# |    explained_variance | 0.669    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4499     |
# |    policy_loss        | -0.0562  |
# |    std                | 0.857    |
# |    value_loss         | 0.000645 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.96     |
# |    ep_rew_mean        | -0.232   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 932      |
# |    iterations         | 4600     |
# |    time_elapsed       | 98       |
# |    total_timesteps    | 92000    |
# | train/                |          |
# |    entropy_loss       | -3.77    |
# |    explained_variance | 0.801    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4599     |
# |    policy_loss        | -0.0948  |
# |    std                | 0.85     |
# |    value_loss         | 0.000942 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.05     |
# |    ep_rew_mean        | -0.227   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 932      |
# |    iterations         | 4700     |
# |    time_elapsed       | 100      |
# |    total_timesteps    | 94000    |
# | train/                |          |
# |    entropy_loss       | -3.73    |
# |    explained_variance | 0.793    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4699     |
# |    policy_loss        | 0.053    |
# |    std                | 0.84     |
# |    value_loss         | 0.000445 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.16     |
# |    ep_rew_mean        | -0.241   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 933      |
# |    iterations         | 4800     |
# |    time_elapsed       | 102      |
# |    total_timesteps    | 96000    |
# | train/                |          |
# |    entropy_loss       | -3.69    |
# |    explained_variance | 0.0935   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4799     |
# |    policy_loss        | -0.19    |
# |    std                | 0.828    |
# |    value_loss         | 0.00519  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.93     |
# |    ep_rew_mean        | -0.233   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 933      |
# |    iterations         | 4900     |
# |    time_elapsed       | 104      |
# |    total_timesteps    | 98000    |
# | train/                |          |
# |    entropy_loss       | -3.68    |
# |    explained_variance | 0.857    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | 0.0627   |
# |    std                | 0.825    |
# |    value_loss         | 0.000514 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3        |
# |    ep_rew_mean        | -0.234   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 934      |
# |    iterations         | 5000     |
# |    time_elapsed       | 107      |
# |    total_timesteps    | 100000   |
# | train/                |          |
# |    entropy_loss       | -3.66    |
# |    explained_variance | 0.842    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4999     |
# |    policy_loss        | -0.04    |
# |    std                | 0.819    |
# |    value_loss         | 0.000272 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.94     |
# |    ep_rew_mean        | -0.227   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 934      |
# |    iterations         | 5100     |
# |    time_elapsed       | 109      |
# |    total_timesteps    | 102000   |
# | train/                |          |
# |    entropy_loss       | -3.65    |
# |    explained_variance | 0.612    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5099     |
# |    policy_loss        | 0.0343   |
# |    std                | 0.816    |
# |    value_loss         | 0.000596 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.25     |
# |    ep_rew_mean        | -0.271   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 935      |
# |    iterations         | 5200     |
# |    time_elapsed       | 111      |
# |    total_timesteps    | 104000   |
# | train/                |          |
# |    entropy_loss       | -3.64    |
# |    explained_variance | 0.534    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5199     |
# |    policy_loss        | 0.00597  |
# |    std                | 0.813    |
# |    value_loss         | 0.000365 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.97     |
# |    ep_rew_mean        | -0.234   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 935      |
# |    iterations         | 5300     |
# |    time_elapsed       | 113      |
# |    total_timesteps    | 106000   |
# | train/                |          |
# |    entropy_loss       | -3.62    |
# |    explained_variance | 0.364    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5299     |
# |    policy_loss        | 0.0289   |
# |    std                | 0.808    |
# |    value_loss         | 0.000919 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.08     |
# |    ep_rew_mean        | -0.238   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 936      |
# |    iterations         | 5400     |
# |    time_elapsed       | 115      |
# |    total_timesteps    | 108000   |
# | train/                |          |
# |    entropy_loss       | -3.58    |
# |    explained_variance | 0.529    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5399     |
# |    policy_loss        | -0.0564  |
# |    std                | 0.798    |
# |    value_loss         | 0.0006   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.86     |
# |    ep_rew_mean        | -0.228   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 936      |
# |    iterations         | 5500     |
# |    time_elapsed       | 117      |
# |    total_timesteps    | 110000   |
# | train/                |          |
# |    entropy_loss       | -3.56    |
# |    explained_variance | 0.667    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5499     |
# |    policy_loss        | 0.0102   |
# |    std                | 0.793    |
# |    value_loss         | 0.000464 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.85     |
# |    ep_rew_mean        | -0.224   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 937      |
# |    iterations         | 5600     |
# |    time_elapsed       | 119      |
# |    total_timesteps    | 112000   |
# | train/                |          |
# |    entropy_loss       | -3.53    |
# |    explained_variance | 0.719    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5599     |
# |    policy_loss        | 0.0192   |
# |    std                | 0.786    |
# |    value_loss         | 0.000316 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.18     |
# |    ep_rew_mean        | -0.253   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 937      |
# |    iterations         | 5700     |
# |    time_elapsed       | 121      |
# |    total_timesteps    | 114000   |
# | train/                |          |
# |    entropy_loss       | -3.5     |
# |    explained_variance | 0.752    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5699     |
# |    policy_loss        | 0.0213   |
# |    std                | 0.778    |
# |    value_loss         | 0.000431 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.95     |
# |    ep_rew_mean        | -0.225   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 938      |
# |    iterations         | 5800     |
# |    time_elapsed       | 123      |
# |    total_timesteps    | 116000   |
# | train/                |          |
# |    entropy_loss       | -3.5     |
# |    explained_variance | 0.61     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | 0.066    |
# |    std                | 0.779    |
# |    value_loss         | 0.000718 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.94     |
# |    ep_rew_mean        | -0.225   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 938      |
# |    iterations         | 5900     |
# |    time_elapsed       | 125      |
# |    total_timesteps    | 118000   |
# | train/                |          |
# |    entropy_loss       | -3.49    |
# |    explained_variance | 0.634    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5899     |
# |    policy_loss        | 0.0125   |
# |    std                | 0.774    |
# |    value_loss         | 0.000204 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.85     |
# |    ep_rew_mean        | -0.232   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 938      |
# |    iterations         | 6000     |
# |    time_elapsed       | 127      |
# |    total_timesteps    | 120000   |
# | train/                |          |
# |    entropy_loss       | -3.46    |
# |    explained_variance | 0.407    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | -0.0281  |
# |    std                | 0.768    |
# |    value_loss         | 0.000313 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.91     |
# |    ep_rew_mean        | -0.235   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 939      |
# |    iterations         | 6100     |
# |    time_elapsed       | 129      |
# |    total_timesteps    | 122000   |
# | train/                |          |
# |    entropy_loss       | -3.45    |
# |    explained_variance | 0.514    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6099     |
# |    policy_loss        | -0.118   |
# |    std                | 0.764    |
# |    value_loss         | 0.00165  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.9      |
# |    ep_rew_mean        | -0.222   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 939      |
# |    iterations         | 6200     |
# |    time_elapsed       | 131      |
# |    total_timesteps    | 124000   |
# | train/                |          |
# |    entropy_loss       | -3.43    |
# |    explained_variance | 0.755    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6199     |
# |    policy_loss        | -0.0638  |
# |    std                | 0.761    |
# |    value_loss         | 0.000655 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.79     |
# |    ep_rew_mean        | -0.22    |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 940      |
# |    iterations         | 6300     |
# |    time_elapsed       | 134      |
# |    total_timesteps    | 126000   |
# | train/                |          |
# |    entropy_loss       | -3.42    |
# |    explained_variance | 0.783    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | 0.117    |
# |    std                | 0.758    |
# |    value_loss         | 0.00112  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.07     |
# |    ep_rew_mean        | -0.239   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 940      |
# |    iterations         | 6400     |
# |    time_elapsed       | 136      |
# |    total_timesteps    | 128000   |
# | train/                |          |
# |    entropy_loss       | -3.4     |
# |    explained_variance | 0.532    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6399     |
# |    policy_loss        | 0.0392   |
# |    std                | 0.752    |
# |    value_loss         | 0.00112  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.74     |
# |    ep_rew_mean        | -0.21    |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 940      |
# |    iterations         | 6500     |
# |    time_elapsed       | 138      |
# |    total_timesteps    | 130000   |
# | train/                |          |
# |    entropy_loss       | -3.38    |
# |    explained_variance | 0.797    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | -0.053   |
# |    std                | 0.747    |
# |    value_loss         | 0.000447 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.94     |
# |    ep_rew_mean        | -0.231   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 941      |
# |    iterations         | 6600     |
# |    time_elapsed       | 140      |
# |    total_timesteps    | 132000   |
# | train/                |          |
# |    entropy_loss       | -3.38    |
# |    explained_variance | 0.633    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6599     |
# |    policy_loss        | -0.0822  |
# |    std                | 0.748    |
# |    value_loss         | 0.00137  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.82     |
# |    ep_rew_mean        | -0.222   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 941      |
# |    iterations         | 6700     |
# |    time_elapsed       | 142      |
# |    total_timesteps    | 134000   |
# | train/                |          |
# |    entropy_loss       | -3.36    |
# |    explained_variance | 0.601    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | 0.02     |
# |    std                | 0.742    |
# |    value_loss         | 0.000572 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.87     |
# |    ep_rew_mean        | -0.231   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 941      |
# |    iterations         | 6800     |
# |    time_elapsed       | 144      |
# |    total_timesteps    | 136000   |
# | train/                |          |
# |    entropy_loss       | -3.35    |
# |    explained_variance | 0.885    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6799     |
# |    policy_loss        | -0.055   |
# |    std                | 0.739    |
# |    value_loss         | 0.000367 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.06     |
# |    ep_rew_mean        | -0.235   |
# ...
# | time/                 |          |
# |    fps                | 963      |
# |    iterations         | 47800    |
# |    time_elapsed       | 991      |
# |    total_timesteps    | 956000   |
# | train/                |          |
# |    entropy_loss       | -0.671   |
# |    explained_variance | 0.95     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 47799    |
# |    policy_loss        | -0.00235 |
# |    std                | 0.311    |
# |    value_loss         | 0.000281 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.92     |
# |    ep_rew_mean        | -0.229   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 963      |
# |    iterations         | 47900    |
# |    time_elapsed       | 993      |
# |    total_timesteps    | 958000   |
# | train/                |          |
# |    entropy_loss       | -0.671   |
# |    explained_variance | 0.881    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 47899    |
# |    policy_loss        | 0.0233   |
# |    std                | 0.31     |
# |    value_loss         | 0.00217  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.86     |
# |    ep_rew_mean        | -0.228   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 963      |
# |    iterations         | 48000    |
# |    time_elapsed       | 995      |
# |    total_timesteps    | 960000   |
# | train/                |          |
# |    entropy_loss       | -0.662   |
# |    explained_variance | 0.897    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 47999    |
# |    policy_loss        | 0.000662 |
# |    std                | 0.309    |
# |    value_loss         | 0.000418 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.91     |
# |    ep_rew_mean        | -0.239   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 963      |
# |    iterations         | 48100    |
# |    time_elapsed       | 998      |
# |    total_timesteps    | 962000   |
# | train/                |          |
# |    entropy_loss       | -0.636   |
# |    explained_variance | 0.978    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48099    |
# |    policy_loss        | -0.00694 |
# |    std                | 0.306    |
# |    value_loss         | 0.000187 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.88     |
# |    ep_rew_mean        | -0.219   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 963      |
# |    iterations         | 48200    |
# |    time_elapsed       | 1000     |
# |    total_timesteps    | 964000   |
# | train/                |          |
# |    entropy_loss       | -0.639   |
# |    explained_variance | 0.935    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48199    |
# |    policy_loss        | 0.00882  |
# |    std                | 0.306    |
# |    value_loss         | 0.00136  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.81     |
# |    ep_rew_mean        | -0.214   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 963      |
# |    iterations         | 48300    |
# |    time_elapsed       | 1002     |
# |    total_timesteps    | 966000   |
# | train/                |          |
# |    entropy_loss       | -0.597   |
# |    explained_variance | 0.78     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48299    |
# |    policy_loss        | 0.00652  |
# |    std                | 0.302    |
# |    value_loss         | 0.000503 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.67     |
# |    ep_rew_mean        | -0.213   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 963      |
# |    iterations         | 48400    |
# |    time_elapsed       | 1004     |
# |    total_timesteps    | 968000   |
# | train/                |          |
# |    entropy_loss       | -0.575   |
# |    explained_variance | 0.979    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48399    |
# |    policy_loss        | 0.00186  |
# |    std                | 0.3      |
# |    value_loss         | 0.000141 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.01     |
# |    ep_rew_mean        | -0.236   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 963      |
# |    iterations         | 48500    |
# |    time_elapsed       | 1006     |
# |    total_timesteps    | 970000   |
# | train/                |          |
# |    entropy_loss       | -0.574   |
# |    explained_variance | 0.954    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48499    |
# |    policy_loss        | -0.00212 |
# |    std                | 0.299    |
# |    value_loss         | 0.000216 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.94     |
# |    ep_rew_mean        | -0.229   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 963      |
# |    iterations         | 48600    |
# |    time_elapsed       | 1008     |
# |    total_timesteps    | 972000   |
# | train/                |          |
# |    entropy_loss       | -0.583   |
# |    explained_variance | 0.904    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48599    |
# |    policy_loss        | -0.00193 |
# |    std                | 0.3      |
# |    value_loss         | 0.000316 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.77     |
# |    ep_rew_mean        | -0.216   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 963      |
# |    iterations         | 48700    |
# |    time_elapsed       | 1010     |
# |    total_timesteps    | 974000   |
# | train/                |          |
# |    entropy_loss       | -0.568   |
# |    explained_variance | 0.951    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48699    |
# |    policy_loss        | 0.00472  |
# |    std                | 0.298    |
# |    value_loss         | 0.000647 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.78     |
# |    ep_rew_mean        | -0.218   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 963      |
# |    iterations         | 48800    |
# |    time_elapsed       | 1012     |
# |    total_timesteps    | 976000   |
# | train/                |          |
# |    entropy_loss       | -0.54    |
# |    explained_variance | 0.988    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48799    |
# |    policy_loss        | 0.000814 |
# |    std                | 0.296    |
# |    value_loss         | 4.62e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.64     |
# |    ep_rew_mean        | -0.207   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 963      |
# |    iterations         | 48900    |
# |    time_elapsed       | 1014     |
# |    total_timesteps    | 978000   |
# | train/                |          |
# |    entropy_loss       | -0.55    |
# |    explained_variance | 0.969    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48899    |
# |    policy_loss        | 0.0103   |
# |    std                | 0.297    |
# |    value_loss         | 0.000312 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.82     |
# |    ep_rew_mean        | -0.223   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 963      |
# |    iterations         | 49000    |
# |    time_elapsed       | 1016     |
# |    total_timesteps    | 980000   |
# | train/                |          |
# |    entropy_loss       | -0.551   |
# |    explained_variance | 0.949    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48999    |
# |    policy_loss        | 0.00211  |
# |    std                | 0.297    |
# |    value_loss         | 0.00028  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.98     |
# |    ep_rew_mean        | -0.233   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 963      |
# |    iterations         | 49100    |
# |    time_elapsed       | 1018     |
# |    total_timesteps    | 982000   |
# | train/                |          |
# |    entropy_loss       | -0.526   |
# |    explained_variance | 0.978    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49099    |
# |    policy_loss        | -0.00469 |
# |    std                | 0.295    |
# |    value_loss         | 0.00018  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76     |
# |    ep_rew_mean        | -0.218   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 963      |
# |    iterations         | 49200    |
# |    time_elapsed       | 1020     |
# |    total_timesteps    | 984000   |
# | train/                |          |
# |    entropy_loss       | -0.518   |
# |    explained_variance | 0.972    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49199    |
# |    policy_loss        | 0.00101  |
# |    std                | 0.294    |
# |    value_loss         | 0.000137 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.68     |
# |    ep_rew_mean        | -0.205   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 963      |
# |    iterations         | 49300    |
# |    time_elapsed       | 1023     |
# |    total_timesteps    | 986000   |
# | train/                |          |
# |    entropy_loss       | -0.509   |
# |    explained_variance | 0.967    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49299    |
# |    policy_loss        | -0.00199 |
# |    std                | 0.293    |
# |    value_loss         | 8.16e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.84     |
# |    ep_rew_mean        | -0.221   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 963      |
# |    iterations         | 49400    |
# |    time_elapsed       | 1025     |
# |    total_timesteps    | 988000   |
# | train/                |          |
# |    entropy_loss       | -0.496   |
# |    explained_variance | 0.942    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49399    |
# |    policy_loss        | 0.00747  |
# |    std                | 0.291    |
# |    value_loss         | 0.000389 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.58     |
# |    ep_rew_mean        | -0.199   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 963      |
# |    iterations         | 49500    |
# |    time_elapsed       | 1027     |
# |    total_timesteps    | 990000   |
# | train/                |          |
# |    entropy_loss       | -0.499   |
# |    explained_variance | 0.976    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49499    |
# |    policy_loss        | 0.00367  |
# |    std                | 0.291    |
# |    value_loss         | 0.000145 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.89     |
# |    ep_rew_mean        | -0.229   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 963      |
# |    iterations         | 49600    |
# |    time_elapsed       | 1029     |
# |    total_timesteps    | 992000   |
# | train/                |          |
# |    entropy_loss       | -0.469   |
# |    explained_variance | 0.988    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49599    |
# |    policy_loss        | -0.00102 |
# |    std                | 0.289    |
# |    value_loss         | 0.000298 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.73     |
# |    ep_rew_mean        | -0.224   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 963      |
# |    iterations         | 49700    |
# |    time_elapsed       | 1031     |
# |    total_timesteps    | 994000   |
# | train/                |          |
# |    entropy_loss       | -0.466   |
# |    explained_variance | 0.992    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49699    |
# |    policy_loss        | -0.00761 |
# |    std                | 0.289    |
# |    value_loss         | 8.68e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.55     |
# |    ep_rew_mean        | -0.196   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 963      |
# |    iterations         | 49800    |
# |    time_elapsed       | 1033     |
# |    total_timesteps    | 996000   |
# | train/                |          |
# |    entropy_loss       | -0.435   |
# |    explained_variance | 0.982    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49799    |
# |    policy_loss        | -0.0021  |
# |    std                | 0.285    |
# |    value_loss         | 0.000105 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.83     |
# |    ep_rew_mean        | -0.226   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 963      |
# |    iterations         | 49900    |
# |    time_elapsed       | 1035     |
# |    total_timesteps    | 998000   |
# | train/                |          |
# |    entropy_loss       | -0.423   |
# |    explained_variance | 0.984    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49899    |
# |    policy_loss        | 0.00143  |
# |    std                | 0.284    |
# |    value_loss         | 0.000155 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76     |
# |    ep_rew_mean        | -0.209   |
# |    success_rate       | 1        |
# | time/                 |          |
# |    fps                | 963      |
# |    iterations         | 50000    |
# |    time_elapsed       | 1037     |
# |    total_timesteps    | 1000000  |
# | train/                |          |
# |    entropy_loss       | -0.422   |
# |    explained_variance | 0.965    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49999    |
# |    policy_loss        | -0.0053  |
# |    std                | 0.284    |
# |    value_loss         | 0.000236 |
# ------------------------------------

# %%
# Save the model and  VecNormalize statistics when saving the agent
model.save("a2c-PandaReachDense-v3")
env.save("vec_normalize.pkl")

# %% [markdown]
# ### Evaluate the agent 📈
# - Now that's our  agent is trained, we need to **check its performance**.
# - Stable-Baselines3 provides a method to do that: `evaluate_policy`

# %%
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize

# Load the saved statistics
eval_env = DummyVecEnv([lambda: gym.make("PandaReachDense-v3")])
eval_env = VecNormalize.load("vec_normalize.pkl", eval_env)

# We need to override the render_mode
eval_env.render_mode = "rgb_array"

#  do not update them at test time
eval_env.training = False
# reward normalization is not needed at test time
eval_env.norm_reward = False

# Load the agent
model = A2C.load("a2c-PandaReachDense-v3")

mean_reward, std_reward = evaluate_policy(model, eval_env)

print(f"Mean reward = {mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# Mean reward = -0.17 +/- 0.08
# /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(

# %% [markdown]
# ### Publish your trained model on the Hub 🔥
# Now that we saw we got good results after the training, we can publish our trained model on the Hub with one line of code.
#
# 📚 The libraries documentation 👉 https://github.com/huggingface/huggingface_sb3/tree/main#hugging-face--x-stable-baselines3-v20

# %% [markdown]
# By using `package_to_hub`, as we already mentionned in the former units, **you evaluate, record a replay, generate a model card of your agent and push it to the hub**.
#
# This way:
# - You can **showcase our work** 🔥
# - You can **visualize your agent playing** 👀
# - You can **share with the community an agent that others can use** 💾
# - You can **access a leaderboard 🏆 to see how well your agent is performing compared to your classmates** 👉 https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard

# %% [markdown]
# To be able to share your model with the community there are three more steps to follow:
#
# 1️⃣ (If it's not already done) create an account to HF ➡ https://huggingface.co/join
#
# 2️⃣ Sign in and then, you need to store your authentication token from the Hugging Face website.
# - Create a new token (https://huggingface.co/settings/tokens) **with write role**
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/create-token.jpg" alt="Create HF Token">
#
# - Copy the token
# - Run the cell below and paste the token

# %%
from huggingface_hub import login
login('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')

# !git config --global credential.helper store
# Out:
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /home/cellverse/.cache/huggingface/token
# Login successful

# %% [markdown]
# If you don't want to use a Google Colab or a Jupyter Notebook, you need to use this command instead: `huggingface-cli login`

# %% [markdown]
# 3️⃣ We're now ready to push our trained agent to the 🤗 Hub 🔥 using `package_to_hub()` function

# %% [markdown]
# For this environment, **running this cell can take approximately 10min**

# %%
from huggingface_sb3 import package_to_hub

package_to_hub(
    model=model,
    model_name=f"a2c-{env_id}",
    model_architecture="A2C",
    env_id=env_id,
    eval_env=eval_env,
    repo_id=f"zhoushch/unit6-a2c-{env_id}", # Change the username
    commit_message="Initial commit",
)
# Out:
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to 1min.
# This is a work in progress: if you encounter a bug, please open an issue.
# Saving video to /tmp/tmpocthu19e/-step-0-to-step-1000.mp4
# Moviepy - Building video /tmp/tmpocthu19e/-step-0-to-step-1000.mp4.
# Moviepy - Writing video /tmp/tmpocthu19e/-step-0-to-step-1000.mp4
# Moviepy - Done !
# Moviepy - video ready /tmp/tmpocthu19e/-step-0-to-step-1000.mp4
# ✘ 'DummyVecEnv' object has no attribute 'video_recorder'
# ✘ We are unable to generate a replay of your agent, the package_to_hub
# process continues
# ✘ Please open an issue at
# https://github.com/huggingface/huggingface_sb3/issues
# ℹ Pushing repo zhoushch/unit6-a2c-PandaReachDense-v3 to the Hugging
# Face Hub
# policy.optimizer.pth:   0%|          | 0.00/48.5k [00:00<?, ?B/s]
# pytorch_variables.pth:   0%|          | 0.00/864 [00:00<?, ?B/s]
# a2c-PandaReachDense-v3.zip:   0%|          | 0.00/114k [00:00<?, ?B/s]
# Upload 5 LFS files:   0%|          | 0/5 [00:00<?, ?it/s]
# policy.pth:   0%|          | 0.00/46.4k [00:00<?, ?B/s]
# vec_normalize.pkl:   0%|          | 0.00/2.64k [00:00<?, ?B/s]
# ℹ Your model is pushed to the Hub. You can view your model here:
# https://huggingface.co/zhoushch/unit6-a2c-PandaReachDense-v3/tree/main/
# CommitInfo(commit_url='https://huggingface.co/zhoushch/unit6-a2c-PandaReachDense-v3/commit/00bab11bf448a9bc7f821f51ef7ae9ec19b5f06f', commit_message='Initial commit', commit_description='', oid='00bab11bf448a9bc7f821f51ef7ae9ec19b5f06f', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# ## Some additional challenges 🏆
# The best way to learn **is to try things by your own**! Why not trying  `PandaPickAndPlace-v3`?
#
# If you want to try more advanced tasks for panda-gym, you need to check what was done using **TQC or SAC** (a more sample-efficient algorithm suited for robotics tasks). In real robotics, you'll use a more sample-efficient algorithm for a simple reason: contrary to a simulation **if you move your robotic arm too much, you have a risk of breaking it**.
#
# PandaPickAndPlace-v1 (this model uses the v1 version of the environment): https://huggingface.co/sb3/tqc-PandaPickAndPlace-v1
#
# And don't hesitate to check panda-gym documentation here: https://panda-gym.readthedocs.io/en/latest/usage/train_with_sb3.html
#
# We provide you the steps to train another agent (optional):
#
# 1. Define the environment called "PandaPickAndPlace-v3"
# 2. Make a vectorized environment
# 3. Add a wrapper to normalize the observations and rewards. [Check the documentation](https://stable-baselines3.readthedocs.io/en/master/guide/vec_envs.html#vecnormalize)
# 4. Create the A2C Model (don't forget verbose=1 to print the training logs).
# 5. Train it for 1M Timesteps
# 6. Save the model and  VecNormalize statistics when saving the agent
# 7. Evaluate your agent
# 8. Publish your trained model on the Hub 🔥 with `package_to_hub`

# %%
# 1 - 2
env_id = "PandaPickAndPlace-v3"
env = make_vec_env(env_id, n_envs=4)

# 3
env = VecNormalize(env, norm_obs=True, norm_reward=True, clip_obs=10.)

# 4
model = A2C(policy = "MultiInputPolicy",
            env = env,
            verbose=1)
# 5
model.learn(1_000_000)
# Out:
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# Using cuda device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.8     |
# |    ep_rew_mean        | -48.8    |
# |    success_rate       | 0.025    |
# | time/                 |          |
# |    fps                | 846      |
# |    iterations         | 100      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -5.68    |
# |    explained_variance | 0.825    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.143   |
# |    std                | 1        |
# |    value_loss         | 0.0974   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.2     |
# |    ep_rew_mean        | -48.1    |
# |    success_rate       | 0.037    |
# | time/                 |          |
# |    fps                | 853      |
# |    iterations         | 200      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -5.69    |
# |    explained_variance | 0.838    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | -0.389   |
# |    std                | 1        |
# |    value_loss         | 0.0828   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 47.3     |
# |    ep_rew_mean        | -47.2    |
# |    success_rate       | 0.07     |
# | time/                 |          |
# |    fps                | 848      |
# |    iterations         | 300      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -5.72    |
# |    explained_variance | 0.446    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -2.04    |
# |    std                | 1.01     |
# |    value_loss         | 1.68     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 47.8     |
# |    ep_rew_mean        | -47.7    |
# |    success_rate       | 0.06     |
# | time/                 |          |
# |    fps                | 847      |
# |    iterations         | 400      |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -5.73    |
# |    explained_variance | 0.812    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | -1.56    |
# |    std                | 1.01     |
# |    value_loss         | 0.209    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.6     |
# |    ep_rew_mean        | -48.5    |
# |    success_rate       | 0.04     |
# | time/                 |          |
# |    fps                | 850      |
# |    iterations         | 500      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -5.75    |
# |    explained_variance | 0.692    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 0.384    |
# |    std                | 1.02     |
# |    value_loss         | 0.124    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.5     |
# |    ep_rew_mean        | -48.5    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 847      |
# |    iterations         | 600      |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -5.76    |
# |    explained_variance | 0.859    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | -0.0558  |
# |    std                | 1.02     |
# |    value_loss         | 0.0295   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48       |
# |    ep_rew_mean        | -48      |
# |    success_rate       | 0.04     |
# | time/                 |          |
# |    fps                | 842      |
# |    iterations         | 700      |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -5.8     |
# |    explained_variance | 0.983    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 0.0637   |
# |    std                | 1.03     |
# |    value_loss         | 0.0158   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.5     |
# |    ep_rew_mean        | -48.5    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 839      |
# |    iterations         | 800      |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -5.79    |
# |    explained_variance | 0.977    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | -0.101   |
# |    std                | 1.03     |
# |    value_loss         | 0.00907  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48       |
# |    ep_rew_mean        | -47.9    |
# |    success_rate       | 0.05     |
# | time/                 |          |
# |    fps                | 837      |
# |    iterations         | 900      |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -5.77    |
# |    explained_variance | 0.476    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | -0.388   |
# |    std                | 1.02     |
# |    value_loss         | 0.0101   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48       |
# |    ep_rew_mean        | -47.9    |
# |    success_rate       | 0.05     |
# | time/                 |          |
# |    fps                | 835      |
# |    iterations         | 1000     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -5.76    |
# |    explained_variance | 0.812    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 0.0715   |
# |    std                | 1.02     |
# |    value_loss         | 0.0115   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.4     |
# |    ep_rew_mean        | -48.4    |
# |    success_rate       | 0.04     |
# | time/                 |          |
# |    fps                | 832      |
# |    iterations         | 1100     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -5.77    |
# |    explained_variance | 0.995    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | -0.49    |
# |    std                | 1.02     |
# |    value_loss         | 0.0183   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.5     |
# |    ep_rew_mean        | -48.5    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 829      |
# |    iterations         | 1200     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -5.74    |
# |    explained_variance | 0.93     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 0.0782   |
# |    std                | 1.02     |
# |    value_loss         | 0.0117   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.5     |
# |    ep_rew_mean        | -48.5    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 829      |
# |    iterations         | 1300     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -5.73    |
# |    explained_variance | -17.7    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | -0.0542  |
# |    std                | 1.01     |
# |    value_loss         | 0.0133   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49       |
# |    ep_rew_mean        | -49      |
# |    success_rate       | 0.02     |
# | time/                 |          |
# |    fps                | 827      |
# |    iterations         | 1400     |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -5.71    |
# |    explained_variance | 0.865    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | -0.0142  |
# |    std                | 1.01     |
# |    value_loss         | 0.00412  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49       |
# |    ep_rew_mean        | -49      |
# |    success_rate       | 0.02     |
# | time/                 |          |
# |    fps                | 826      |
# |    iterations         | 1500     |
# |    time_elapsed       | 36       |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -5.71    |
# |    explained_variance | 0.849    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | 0.129    |
# |    std                | 1.01     |
# |    value_loss         | 0.0115   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -50      |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 826      |
# |    iterations         | 1600     |
# |    time_elapsed       | 38       |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -5.71    |
# |    explained_variance | 0.951    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | -0.12    |
# |    std                | 1.01     |
# |    value_loss         | 0.00513  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49.5     |
# |    ep_rew_mean        | -49.5    |
# |    success_rate       | 0.01     |
# | time/                 |          |
# |    fps                | 826      |
# |    iterations         | 1700     |
# |    time_elapsed       | 41       |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -5.7     |
# |    explained_variance | 0.939    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | -0.0809  |
# |    std                | 1.01     |
# |    value_loss         | 0.00238  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49.5     |
# |    ep_rew_mean        | -49.5    |
# |    success_rate       | 0.01     |
# | time/                 |          |
# |    fps                | 826      |
# |    iterations         | 1800     |
# |    time_elapsed       | 43       |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -5.7     |
# |    explained_variance | 0.857    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | -0.131   |
# |    std                | 1.01     |
# |    value_loss         | 0.00603  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49       |
# |    ep_rew_mean        | -49      |
# |    success_rate       | 0.02     |
# | time/                 |          |
# |    fps                | 827      |
# |    iterations         | 1900     |
# |    time_elapsed       | 45       |
# |    total_timesteps    | 38000    |
# | train/                |          |
# |    entropy_loss       | -5.69    |
# |    explained_variance | 0.938    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | -0.225   |
# |    std                | 1        |
# |    value_loss         | 0.00512  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.5     |
# |    ep_rew_mean        | -48.5    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 828      |
# |    iterations         | 2000     |
# |    time_elapsed       | 48       |
# |    total_timesteps    | 40000    |
# | train/                |          |
# |    entropy_loss       | -5.71    |
# |    explained_variance | 0.156    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | 3.21     |
# |    std                | 1.01     |
# |    value_loss         | 1.84     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 47.5     |
# |    ep_rew_mean        | -47.5    |
# |    success_rate       | 0.05     |
# | time/                 |          |
# |    fps                | 829      |
# |    iterations         | 2100     |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 42000    |
# | train/                |          |
# |    entropy_loss       | -5.71    |
# |    explained_variance | 0.962    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | 0.209    |
# |    std                | 1.01     |
# |    value_loss         | 0.00235  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48       |
# |    ep_rew_mean        | -48      |
# |    success_rate       | 0.04     |
# | time/                 |          |
# |    fps                | 830      |
# |    iterations         | 2200     |
# |    time_elapsed       | 53       |
# |    total_timesteps    | 44000    |
# | train/                |          |
# |    entropy_loss       | -5.69    |
# |    explained_variance | 0.89     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | 0.14     |
# |    std                | 1        |
# |    value_loss         | 0.00249  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 47.5     |
# |    ep_rew_mean        | -47.5    |
# |    success_rate       | 0.05     |
# | time/                 |          |
# |    fps                | 830      |
# |    iterations         | 2300     |
# |    time_elapsed       | 55       |
# |    total_timesteps    | 46000    |
# | train/                |          |
# |    entropy_loss       | -5.71    |
# |    explained_variance | 0.947    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | 0.0168   |
# |    std                | 1.01     |
# |    value_loss         | 0.00135  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49.5     |
# |    ep_rew_mean        | -49.5    |
# |    success_rate       | 0.01     |
# | time/                 |          |
# |    fps                | 829      |
# |    iterations         | 2400     |
# |    time_elapsed       | 57       |
# |    total_timesteps    | 48000    |
# | train/                |          |
# |    entropy_loss       | -5.72    |
# |    explained_variance | 0.854    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | -0.00314 |
# |    std                | 1.01     |
# |    value_loss         | 0.00131  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -50      |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 828      |
# |    iterations         | 2500     |
# |    time_elapsed       | 60       |
# |    total_timesteps    | 50000    |
# | train/                |          |
# |    entropy_loss       | -5.74    |
# |    explained_variance | 0.981    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | -0.0877  |
# |    std                | 1.02     |
# |    value_loss         | 0.000593 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.5     |
# |    ep_rew_mean        | -48.5    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 828      |
# |    iterations         | 2600     |
# |    time_elapsed       | 62       |
# |    total_timesteps    | 52000    |
# | train/                |          |
# |    entropy_loss       | -5.76    |
# |    explained_variance | 0.833    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | 0.0127   |
# |    std                | 1.02     |
# |    value_loss         | 0.00468  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 47.5     |
# |    ep_rew_mean        | -47.5    |
# |    success_rate       | 0.05     |
# | time/                 |          |
# |    fps                | 829      |
# |    iterations         | 2700     |
# |    time_elapsed       | 65       |
# |    total_timesteps    | 54000    |
# | train/                |          |
# |    entropy_loss       | -5.79    |
# |    explained_variance | 0.933    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | -0.0223  |
# |    std                | 1.03     |
# |    value_loss         | 0.00694  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 47.5     |
# |    ep_rew_mean        | -47.5    |
# |    success_rate       | 0.05     |
# | time/                 |          |
# |    fps                | 830      |
# |    iterations         | 2800     |
# |    time_elapsed       | 67       |
# |    total_timesteps    | 56000    |
# | train/                |          |
# |    entropy_loss       | -5.77    |
# |    explained_variance | 0.92     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | 0.167    |
# |    std                | 1.03     |
# |    value_loss         | 0.0123   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48       |
# |    ep_rew_mean        | -48      |
# |    success_rate       | 0.04     |
# | time/                 |          |
# |    fps                | 831      |
# |    iterations         | 2900     |
# |    time_elapsed       | 69       |
# |    total_timesteps    | 58000    |
# | train/                |          |
# |    entropy_loss       | -5.78    |
# |    explained_variance | -0.251   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | 4.05     |
# |    std                | 1.03     |
# |    value_loss         | 1.63     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 47.1     |
# |    ep_rew_mean        | -47      |
# |    success_rate       | 0.06     |
# | time/                 |          |
# |    fps                | 833      |
# |    iterations         | 3000     |
# |    time_elapsed       | 72       |
# |    total_timesteps    | 60000    |
# | train/                |          |
# |    entropy_loss       | -5.8     |
# |    explained_variance | 0.997    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.0219   |
# |    std                | 1.03     |
# |    value_loss         | 0.000547 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 47.5     |
# |    ep_rew_mean        | -47.5    |
# |    success_rate       | 0.05     |
# | time/                 |          |
# |    fps                | 834      |
# |    iterations         | 3100     |
# |    time_elapsed       | 74       |
# |    total_timesteps    | 62000    |
# | train/                |          |
# |    entropy_loss       | -5.8     |
# |    explained_variance | 0.896    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | -0.0538  |
# |    std                | 1.03     |
# |    value_loss         | 0.00113  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.5     |
# |    ep_rew_mean        | -48.5    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 834      |
# |    iterations         | 3200     |
# |    time_elapsed       | 76       |
# |    total_timesteps    | 64000    |
# | train/                |          |
# |    entropy_loss       | -5.78    |
# |    explained_variance | 0.997    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | -0.0197  |
# |    std                | 1.03     |
# |    value_loss         | 0.000206 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49       |
# |    ep_rew_mean        | -49      |
# |    success_rate       | 0.02     |
# | time/                 |          |
# |    fps                | 835      |
# |    iterations         | 3300     |
# |    time_elapsed       | 79       |
# |    total_timesteps    | 66000    |
# | train/                |          |
# |    entropy_loss       | -5.76    |
# |    explained_variance | 0.993    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | -0.0174  |
# |    std                | 1.02     |
# |    value_loss         | 0.000246 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49.5     |
# |    ep_rew_mean        | -49.5    |
# |    success_rate       | 0.01     |
# | time/                 |          |
# |    fps                | 835      |
# |    iterations         | 3400     |
# |    time_elapsed       | 81       |
# |    total_timesteps    | 68000    |
# | train/                |          |
# |    entropy_loss       | -5.75    |
# |    explained_variance | -11.6    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | 0.5      |
# |    std                | 1.02     |
# |    value_loss         | 0.0379   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49       |
# |    ep_rew_mean        | -49      |
# |    success_rate       | 0.02     |
# | time/                 |          |
# |    fps                | 836      |
# |    iterations         | 3500     |
# |    time_elapsed       | 83       |
# |    total_timesteps    | 70000    |
# | train/                |          |
# |    entropy_loss       | -5.74    |
# |    explained_variance | 0.955    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | 0.0478   |
# |    std                | 1.02     |
# |    value_loss         | 0.000445 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49.5     |
# |    ep_rew_mean        | -49.5    |
# |    success_rate       | 0.01     |
# | time/                 |          |
# |    fps                | 835      |
# |    iterations         | 3600     |
# |    time_elapsed       | 86       |
# |    total_timesteps    | 72000    |
# | train/                |          |
# |    entropy_loss       | -5.72    |
# |    explained_variance | 0.977    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | -0.0824  |
# |    std                | 1.01     |
# |    value_loss         | 0.000384 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49.5     |
# |    ep_rew_mean        | -49.5    |
# |    success_rate       | 0.01     |
# | time/                 |          |
# |    fps                | 836      |
# |    iterations         | 3700     |
# |    time_elapsed       | 88       |
# |    total_timesteps    | 74000    |
# | train/                |          |
# |    entropy_loss       | -5.72    |
# |    explained_variance | 0.887    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | -0.193   |
# |    std                | 1.01     |
# |    value_loss         | 0.00233  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49       |
# |    ep_rew_mean        | -49      |
# |    success_rate       | 0.02     |
# | time/                 |          |
# |    fps                | 836      |
# |    iterations         | 3800     |
# |    time_elapsed       | 90       |
# |    total_timesteps    | 76000    |
# | train/                |          |
# |    entropy_loss       | -5.74    |
# |    explained_variance | 0.819    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | -0.182   |
# |    std                | 1.02     |
# |    value_loss         | 0.00417  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49       |
# |    ep_rew_mean        | -49      |
# |    success_rate       | 0.02     |
# | time/                 |          |
# |    fps                | 836      |
# |    iterations         | 3900     |
# |    time_elapsed       | 93       |
# |    total_timesteps    | 78000    |
# | train/                |          |
# |    entropy_loss       | -5.74    |
# |    explained_variance | 0.94     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | -0.0646  |
# |    std                | 1.02     |
# |    value_loss         | 0.000413 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48       |
# |    ep_rew_mean        | -48      |
# |    success_rate       | 0.04     |
# | time/                 |          |
# |    fps                | 837      |
# |    iterations         | 4000     |
# |    time_elapsed       | 95       |
# |    total_timesteps    | 80000    |
# | train/                |          |
# |    entropy_loss       | -5.74    |
# |    explained_variance | 0.966    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.0215   |
# |    std                | 1.02     |
# |    value_loss         | 0.000271 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 47.5     |
# |    ep_rew_mean        | -47.5    |
# |    success_rate       | 0.05     |
# | time/                 |          |
# |    fps                | 837      |
# |    iterations         | 4100     |
# |    time_elapsed       | 97       |
# |    total_timesteps    | 82000    |
# | train/                |          |
# |    entropy_loss       | -5.74    |
# |    explained_variance | 0.968    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | -0.0678  |
# |    std                | 1.02     |
# |    value_loss         | 0.000229 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 47.1     |
# |    ep_rew_mean        | -47      |
# |    success_rate       | 0.06     |
# | time/                 |          |
# |    fps                | 837      |
# |    iterations         | 4200     |
# |    time_elapsed       | 100      |
# |    total_timesteps    | 84000    |
# | train/                |          |
# |    entropy_loss       | -5.72    |
# |    explained_variance | 0.992    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | 0.000553 |
# |    std                | 1.01     |
# |    value_loss         | 8.32e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48       |
# |    ep_rew_mean        | -48      |
# |    success_rate       | 0.04     |
# | time/                 |          |
# |    fps                | 838      |
# |    iterations         | 4300     |
# |    time_elapsed       | 102      |
# |    total_timesteps    | 86000    |
# | train/                |          |
# |    entropy_loss       | -5.71    |
# |    explained_variance | 0.992    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | -0.0299  |
# |    std                | 1.01     |
# |    value_loss         | 8.3e-05  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49       |
# |    ep_rew_mean        | -49      |
# |    success_rate       | 0.02     |
# | time/                 |          |
# |    fps                | 838      |
# |    iterations         | 4400     |
# |    time_elapsed       | 104      |
# |    total_timesteps    | 88000    |
# | train/                |          |
# |    entropy_loss       | -5.7     |
# |    explained_variance | 0.954    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | 0.0426   |
# |    std                | 1.01     |
# |    value_loss         | 0.000138 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49.5     |
# |    ep_rew_mean        | -49.5    |
# |    success_rate       | 0.01     |
# | time/                 |          |
# |    fps                | 838      |
# |    iterations         | 4500     |
# |    time_elapsed       | 107      |
# |    total_timesteps    | 90000    |
# | train/                |          |
# |    entropy_loss       | -5.67    |
# |    explained_variance | 0.646    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4499     |
# |    policy_loss        | -0.0238  |
# |    std                | 1        |
# |    value_loss         | 0.000157 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.5     |
# |    ep_rew_mean        | -48.5    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 839      |
# |    iterations         | 4600     |
# |    time_elapsed       | 109      |
# |    total_timesteps    | 92000    |
# | train/                |          |
# |    entropy_loss       | -5.68    |
# |    explained_variance | 0.806    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4599     |
# |    policy_loss        | -0.0696  |
# |    std                | 1.01     |
# |    value_loss         | 0.00028  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.5     |
# |    ep_rew_mean        | -48.5    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 839      |
# |    iterations         | 4700     |
# |    time_elapsed       | 112      |
# |    total_timesteps    | 94000    |
# | train/                |          |
# |    entropy_loss       | -5.66    |
# |    explained_variance | 0.995    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4699     |
# |    policy_loss        | 0.00774  |
# |    std                | 1        |
# |    value_loss         | 4.49e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 47.5     |
# |    ep_rew_mean        | -47.5    |
# |    success_rate       | 0.05     |
# | time/                 |          |
# |    fps                | 839      |
# |    iterations         | 4800     |
# |    time_elapsed       | 114      |
# |    total_timesteps    | 96000    |
# | train/                |          |
# |    entropy_loss       | -5.65    |
# |    explained_variance | 0.982    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4799     |
# |    policy_loss        | -0.012   |
# |    std                | 0.996    |
# |    value_loss         | 0.000193 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 47.5     |
# |    ep_rew_mean        | -47.5    |
# |    success_rate       | 0.05     |
# | time/                 |          |
# |    fps                | 839      |
# |    iterations         | 4900     |
# |    time_elapsed       | 116      |
# |    total_timesteps    | 98000    |
# | train/                |          |
# |    entropy_loss       | -5.64    |
# |    explained_variance | 0.83     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | 0.0248   |
# |    std                | 0.994    |
# |    value_loss         | 0.000108 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48       |
# |    ep_rew_mean        | -48      |
# |    success_rate       | 0.04     |
# | time/                 |          |
# |    fps                | 839      |
# |    iterations         | 5000     |
# |    time_elapsed       | 119      |
# |    total_timesteps    | 100000   |
# | train/                |          |
# |    entropy_loss       | -5.64    |
# |    explained_variance | 0.843    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4999     |
# |    policy_loss        | 0.0304   |
# |    std                | 0.995    |
# |    value_loss         | 0.000354 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49       |
# |    ep_rew_mean        | -49      |
# |    success_rate       | 0.02     |
# | time/                 |          |
# |    fps                | 839      |
# |    iterations         | 5100     |
# |    time_elapsed       | 121      |
# |    total_timesteps    | 102000   |
# | train/                |          |
# |    entropy_loss       | -5.66    |
# |    explained_variance | 0.261    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5099     |
# |    policy_loss        | -0.451   |
# |    std                | 1        |
# |    value_loss         | 0.0496   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49       |
# |    ep_rew_mean        | -49      |
# |    success_rate       | 0.02     |
# | time/                 |          |
# |    fps                | 839      |
# |    iterations         | 5200     |
# |    time_elapsed       | 123      |
# |    total_timesteps    | 104000   |
# | train/                |          |
# |    entropy_loss       | -5.66    |
# |    explained_variance | 0.923    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5199     |
# |    policy_loss        | 0.0112   |
# |    std                | 1        |
# |    value_loss         | 3e-05    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49       |
# |    ep_rew_mean        | -49      |
# |    success_rate       | 0.02     |
# | time/                 |          |
# |    fps                | 839      |
# |    iterations         | 5300     |
# |    time_elapsed       | 126      |
# |    total_timesteps    | 106000   |
# | train/                |          |
# |    entropy_loss       | -5.66    |
# |    explained_variance | 0.752    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5299     |
# |    policy_loss        | -0.0104  |
# |    std                | 1        |
# |    value_loss         | 9.24e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.5     |
# |    ep_rew_mean        | -48.5    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 839      |
# |    iterations         | 5400     |
# |    time_elapsed       | 128      |
# |    total_timesteps    | 108000   |
# | train/                |          |
# |    entropy_loss       | -5.67    |
# |    explained_variance | 0.983    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5399     |
# |    policy_loss        | -0.00481 |
# |    std                | 1        |
# |    value_loss         | 1.97e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 47.5     |
# |    ep_rew_mean        | -47.5    |
# |    success_rate       | 0.05     |
# | time/                 |          |
# |    fps                | 839      |
# |    iterations         | 5500     |
# |    time_elapsed       | 131      |
# |    total_timesteps    | 110000   |
# | train/                |          |
# |    entropy_loss       | -5.66    |
# |    explained_variance | 0.909    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5499     |
# |    policy_loss        | -0.00722 |
# |    std                | 1        |
# |    value_loss         | 7.84e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49       |
# |    ep_rew_mean        | -49      |
# |    success_rate       | 0.02     |
# | time/                 |          |
# |    fps                | 839      |
# |    iterations         | 5600     |
# |    time_elapsed       | 133      |
# |    total_timesteps    | 112000   |
# | train/                |          |
# |    entropy_loss       | -5.65    |
# |    explained_variance | -0.0747  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5599     |
# |    policy_loss        | -0.0218  |
# |    std                | 0.998    |
# |    value_loss         | 8.82e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -50      |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 839      |
# |    iterations         | 5700     |
# |    time_elapsed       | 135      |
# |    total_timesteps    | 114000   |
# | train/                |          |
# |    entropy_loss       | -5.64    |
# |    explained_variance | 0.839    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5699     |
# |    policy_loss        | 0.00792  |
# |    std                | 0.995    |
# |    value_loss         | 3.14e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49       |
# |    ep_rew_mean        | -49      |
# |    success_rate       | 0.02     |
# | time/                 |          |
# |    fps                | 839      |
# |    iterations         | 5800     |
# |    time_elapsed       | 138      |
# |    total_timesteps    | 116000   |
# | train/                |          |
# |    entropy_loss       | -5.64    |
# |    explained_variance | 0.976    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | -0.0298  |
# |    std                | 0.996    |
# |    value_loss         | 0.000114 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 47.5     |
# |    ep_rew_mean        | -47.5    |
# |    success_rate       | 0.05     |
# | time/                 |          |
# |    fps                | 839      |
# |    iterations         | 5900     |
# |    time_elapsed       | 140      |
# |    total_timesteps    | 118000   |
# | train/                |          |
# |    entropy_loss       | -5.6     |
# |    explained_variance | 0.955    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5899     |
# |    policy_loss        | 0.0166   |
# |    std                | 0.986    |
# |    value_loss         | 4.36e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48       |
# |    ep_rew_mean        | -48      |
# |    success_rate       | 0.04     |
# | time/                 |          |
# |    fps                | 839      |
# |    iterations         | 6000     |
# |    time_elapsed       | 142      |
# |    total_timesteps    | 120000   |
# | train/                |          |
# |    entropy_loss       | -5.61    |
# |    explained_variance | 0.902    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | 0.0287   |
# |    std                | 0.988    |
# |    value_loss         | 8.78e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49.5     |
# |    ep_rew_mean        | -49.5    |
# |    success_rate       | 0.01     |
# | time/                 |          |
# |    fps                | 839      |
# |    iterations         | 6100     |
# |    time_elapsed       | 145      |
# |    total_timesteps    | 122000   |
# | train/                |          |
# |    entropy_loss       | -5.6     |
# |    explained_variance | -2.22    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6099     |
# |    policy_loss        | -0.325   |
# |    std                | 0.988    |
# |    value_loss         | 0.0137   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -50      |
# |    success_rate       | 0        |
# | time/                 |          |
# |    fps                | 839      |
# |    iterations         | 6200     |
# |    time_elapsed       | 147      |
# |    total_timesteps    | 124000   |
# | train/                |          |
# |    entropy_loss       | -5.6     |
# |    explained_variance | 0.981    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6199     |
# |    policy_loss        | -0.0109  |
# |    std                | 0.984    |
# |    value_loss         | 2.49e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49       |
# |    ep_rew_mean        | -49      |
# |    success_rate       | 0.02     |
# | time/                 |          |
# |    fps                | 839      |
# |    iterations         | 6300     |
# |    time_elapsed       | 150      |
# |    total_timesteps    | 126000   |
# | train/                |          |
# |    entropy_loss       | -5.58    |
# |    explained_variance | 0.989    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | -0.0285  |
# |    std                | 0.98     |
# |    value_loss         | 4.95e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 47.5     |
# |    ep_rew_mean        | -47.5    |
# |    success_rate       | 0.05     |
# | time/                 |          |
# |    fps                | 839      |
# |    iterations         | 6400     |
# |    time_elapsed       | 152      |
# |    total_timesteps    | 128000   |
# | train/                |          |
# |    entropy_loss       | -5.57    |
# |    explained_variance | 0.986    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6399     |
# |    policy_loss        | -0.0194  |
# |    std                | 0.978    |
# |    value_loss         | 2.28e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 47.3     |
# |    ep_rew_mean        | -47.2    |
# |    success_rate       | 0.06     |
# | time/                 |          |
# |    fps                | 839      |
# |    iterations         | 6500     |
# |    time_elapsed       | 154      |
# |    total_timesteps    | 130000   |
# | train/                |          |
# |    entropy_loss       | -5.57    |
# |    explained_variance | 0.993    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | -0.00457 |
# |    std                | 0.977    |
# |    value_loss         | 1.71e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 47.8     |
# |    ep_rew_mean        | -47.8    |
# |    success_rate       | 0.05     |
# | time/                 |          |
# |    fps                | 839      |
# |    iterations         | 6600     |
# |    time_elapsed       | 157      |
# |    total_timesteps    | 132000   |
# | train/                |          |
# |    entropy_loss       | -5.57    |
# |    explained_variance | -0.0432  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6599     |
# |    policy_loss        | -0.0568  |
# |    std                | 0.978    |
# |    value_loss         | 0.000173 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.8     |
# |    ep_rew_mean        | -48.8    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 839      |
# |    iterations         | 6700     |
# |    time_elapsed       | 159      |
# |    total_timesteps    | 134000   |
# | train/                |          |
# |    entropy_loss       | -5.58    |
# |    explained_variance | 0.974    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | 0.000444 |
# |    std                | 0.98     |
# |    value_loss         | 4.22e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49.3     |
# |    ep_rew_mean        | -49.3    |
# |    success_rate       | 0.02     |
# | time/                 |          |
# |    fps                | 840      |
# ...
# | time/                 |          |
# |    fps                | 860      |
# |    iterations         | 47800    |
# |    time_elapsed       | 1111     |
# |    total_timesteps    | 956000   |
# | train/                |          |
# |    entropy_loss       | -2.99    |
# |    explained_variance | 0.981    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 47799    |
# |    policy_loss        | -0.00145 |
# |    std                | 0.523    |
# |    value_loss         | 7.59e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.8     |
# |    ep_rew_mean        | -48.8    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 860      |
# |    iterations         | 47900    |
# |    time_elapsed       | 1113     |
# |    total_timesteps    | 958000   |
# | train/                |          |
# |    entropy_loss       | -2.97    |
# |    explained_variance | 0.966    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 47899    |
# |    policy_loss        | 0.002    |
# |    std                | 0.52     |
# |    value_loss         | 5.51e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49.3     |
# |    ep_rew_mean        | -49.3    |
# |    success_rate       | 0.02     |
# | time/                 |          |
# |    fps                | 860      |
# |    iterations         | 48000    |
# |    time_elapsed       | 1116     |
# |    total_timesteps    | 960000   |
# | train/                |          |
# |    entropy_loss       | -2.96    |
# |    explained_variance | 0.959    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 47999    |
# |    policy_loss        | 0.000787 |
# |    std                | 0.52     |
# |    value_loss         | 7.02e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49       |
# |    ep_rew_mean        | -49      |
# |    success_rate       | 0.02     |
# | time/                 |          |
# |    fps                | 859      |
# |    iterations         | 48100    |
# |    time_elapsed       | 1118     |
# |    total_timesteps    | 962000   |
# | train/                |          |
# |    entropy_loss       | -2.93    |
# |    explained_variance | 0.959    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48099    |
# |    policy_loss        | 0.00238  |
# |    std                | 0.516    |
# |    value_loss         | 4.72e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.5     |
# |    ep_rew_mean        | -48.5    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 859      |
# |    iterations         | 48200    |
# |    time_elapsed       | 1121     |
# |    total_timesteps    | 964000   |
# | train/                |          |
# |    entropy_loss       | -2.92    |
# |    explained_variance | 0.727    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48199    |
# |    policy_loss        | -0.00446 |
# |    std                | 0.515    |
# |    value_loss         | 1.34e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 47.5     |
# |    ep_rew_mean        | -47.5    |
# |    success_rate       | 0.05     |
# | time/                 |          |
# |    fps                | 859      |
# |    iterations         | 48300    |
# |    time_elapsed       | 1123     |
# |    total_timesteps    | 966000   |
# | train/                |          |
# |    entropy_loss       | -2.88    |
# |    explained_variance | 0.796    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48299    |
# |    policy_loss        | -0.00422 |
# |    std                | 0.509    |
# |    value_loss         | 3.92e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 46.6     |
# |    ep_rew_mean        | -46.6    |
# |    success_rate       | 0.07     |
# | time/                 |          |
# |    fps                | 859      |
# |    iterations         | 48400    |
# |    time_elapsed       | 1125     |
# |    total_timesteps    | 968000   |
# | train/                |          |
# |    entropy_loss       | -2.87    |
# |    explained_variance | 0.952    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48399    |
# |    policy_loss        | -0.00925 |
# |    std                | 0.508    |
# |    value_loss         | 3e-05    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.1     |
# |    ep_rew_mean        | -48.1    |
# |    success_rate       | 0.04     |
# | time/                 |          |
# |    fps                | 859      |
# |    iterations         | 48500    |
# |    time_elapsed       | 1128     |
# |    total_timesteps    | 970000   |
# | train/                |          |
# |    entropy_loss       | -2.86    |
# |    explained_variance | 0.99     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48499    |
# |    policy_loss        | 0.00171  |
# |    std                | 0.507    |
# |    value_loss         | 2.58e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.6     |
# |    ep_rew_mean        | -48.6    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 859      |
# |    iterations         | 48600    |
# |    time_elapsed       | 1130     |
# |    total_timesteps    | 972000   |
# | train/                |          |
# |    entropy_loss       | -2.86    |
# |    explained_variance | 0.97     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48599    |
# |    policy_loss        | -0.00145 |
# |    std                | 0.507    |
# |    value_loss         | 2.78e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.5     |
# |    ep_rew_mean        | -48.4    |
# |    success_rate       | 0.04     |
# | time/                 |          |
# |    fps                | 859      |
# |    iterations         | 48700    |
# |    time_elapsed       | 1132     |
# |    total_timesteps    | 974000   |
# | train/                |          |
# |    entropy_loss       | -2.84    |
# |    explained_variance | 0.957    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48699    |
# |    policy_loss        | 0.000591 |
# |    std                | 0.505    |
# |    value_loss         | 1.97e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48       |
# |    ep_rew_mean        | -47.9    |
# |    success_rate       | 0.05     |
# | time/                 |          |
# |    fps                | 859      |
# |    iterations         | 48800    |
# |    time_elapsed       | 1135     |
# |    total_timesteps    | 976000   |
# | train/                |          |
# |    entropy_loss       | -2.83    |
# |    explained_variance | 0.988    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48799    |
# |    policy_loss        | 0.000436 |
# |    std                | 0.503    |
# |    value_loss         | 1.56e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 46.2     |
# |    ep_rew_mean        | -46.1    |
# |    success_rate       | 0.08     |
# | time/                 |          |
# |    fps                | 859      |
# |    iterations         | 48900    |
# |    time_elapsed       | 1137     |
# |    total_timesteps    | 978000   |
# | train/                |          |
# |    entropy_loss       | -2.81    |
# |    explained_variance | 0.986    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48899    |
# |    policy_loss        | -0.00915 |
# |    std                | 0.501    |
# |    value_loss         | 1.08e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 47.1     |
# |    ep_rew_mean        | -47      |
# |    success_rate       | 0.06     |
# | time/                 |          |
# |    fps                | 859      |
# |    iterations         | 49000    |
# |    time_elapsed       | 1139     |
# |    total_timesteps    | 980000   |
# | train/                |          |
# |    entropy_loss       | -2.82    |
# |    explained_variance | 0.996    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48999    |
# |    policy_loss        | 0.000193 |
# |    std                | 0.501    |
# |    value_loss         | 1.61e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.5     |
# |    ep_rew_mean        | -48.5    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 859      |
# |    iterations         | 49100    |
# |    time_elapsed       | 1142     |
# |    total_timesteps    | 982000   |
# | train/                |          |
# |    entropy_loss       | -2.81    |
# |    explained_variance | 0.811    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49099    |
# |    policy_loss        | -0.00343 |
# |    std                | 0.501    |
# |    value_loss         | 4.17e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48       |
# |    ep_rew_mean        | -48      |
# |    success_rate       | 0.04     |
# | time/                 |          |
# |    fps                | 859      |
# |    iterations         | 49200    |
# |    time_elapsed       | 1144     |
# |    total_timesteps    | 984000   |
# | train/                |          |
# |    entropy_loss       | -2.81    |
# |    explained_variance | 0.834    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49199    |
# |    policy_loss        | -0.00441 |
# |    std                | 0.5      |
# |    value_loss         | 1.27e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 47.1     |
# |    ep_rew_mean        | -47      |
# |    success_rate       | 0.06     |
# | time/                 |          |
# |    fps                | 859      |
# |    iterations         | 49300    |
# |    time_elapsed       | 1146     |
# |    total_timesteps    | 986000   |
# | train/                |          |
# |    entropy_loss       | -2.8     |
# |    explained_variance | 0.975    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49299    |
# |    policy_loss        | -0.00118 |
# |    std                | 0.5      |
# |    value_loss         | 4.56e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 46.6     |
# |    ep_rew_mean        | -46.6    |
# |    success_rate       | 0.08     |
# | time/                 |          |
# |    fps                | 859      |
# |    iterations         | 49400    |
# |    time_elapsed       | 1149     |
# |    total_timesteps    | 988000   |
# | train/                |          |
# |    entropy_loss       | -2.79    |
# |    explained_variance | 0.667    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49399    |
# |    policy_loss        | -0.00342 |
# |    std                | 0.499    |
# |    value_loss         | 6.77e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.1     |
# |    ep_rew_mean        | -48.1    |
# |    success_rate       | 0.05     |
# | time/                 |          |
# |    fps                | 859      |
# |    iterations         | 49500    |
# |    time_elapsed       | 1151     |
# |    total_timesteps    | 990000   |
# | train/                |          |
# |    entropy_loss       | -2.77    |
# |    explained_variance | 0.961    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49499    |
# |    policy_loss        | -0.00141 |
# |    std                | 0.496    |
# |    value_loss         | 2.26e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 47.1     |
# |    ep_rew_mean        | -47.1    |
# |    success_rate       | 0.07     |
# | time/                 |          |
# |    fps                | 859      |
# |    iterations         | 49600    |
# |    time_elapsed       | 1153     |
# |    total_timesteps    | 992000   |
# | train/                |          |
# |    entropy_loss       | -2.76    |
# |    explained_variance | 0.833    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49599    |
# |    policy_loss        | -0.00376 |
# |    std                | 0.495    |
# |    value_loss         | 7.82e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.5     |
# |    ep_rew_mean        | -48.5    |
# |    success_rate       | 0.03     |
# | time/                 |          |
# |    fps                | 859      |
# |    iterations         | 49700    |
# |    time_elapsed       | 1156     |
# |    total_timesteps    | 994000   |
# | train/                |          |
# |    entropy_loss       | -2.75    |
# |    explained_variance | 0.958    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49699    |
# |    policy_loss        | 0.000934 |
# |    std                | 0.494    |
# |    value_loss         | 4.38e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.4     |
# |    ep_rew_mean        | -48.4    |
# |    success_rate       | 0.04     |
# | time/                 |          |
# |    fps                | 859      |
# |    iterations         | 49800    |
# |    time_elapsed       | 1158     |
# |    total_timesteps    | 996000   |
# | train/                |          |
# |    entropy_loss       | -2.72    |
# |    explained_variance | 0.948    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49799    |
# |    policy_loss        | -0.00803 |
# |    std                | 0.491    |
# |    value_loss         | 1.71e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48.6     |
# |    ep_rew_mean        | -48.5    |
# |    success_rate       | 0.04     |
# | time/                 |          |
# |    fps                | 859      |
# |    iterations         | 49900    |
# |    time_elapsed       | 1160     |
# |    total_timesteps    | 998000   |
# | train/                |          |
# |    entropy_loss       | -2.73    |
# |    explained_variance | 0.98     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49899    |
# |    policy_loss        | 0.000164 |
# |    std                | 0.492    |
# |    value_loss         | 7.78e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49.2     |
# |    ep_rew_mean        | -49.2    |
# |    success_rate       | 0.02     |
# | time/                 |          |
# |    fps                | 859      |
# |    iterations         | 50000    |
# |    time_elapsed       | 1163     |
# |    total_timesteps    | 1000000  |
# | train/                |          |
# |    entropy_loss       | -2.72    |
# |    explained_variance | 0.552    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49999    |
# |    policy_loss        | -0.00116 |
# |    std                | 0.491    |
# |    value_loss         | 9.24e-07 |
# ------------------------------------

# %%
# 6
model_name = "a2c-PandaPickAndPlace-v3";
model.save(model_name)
env.save("vec_normalize.pkl")

# 7
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize

# Load the saved statistics
eval_env = DummyVecEnv([lambda: gym.make("PandaPickAndPlace-v3")])
eval_env = VecNormalize.load("vec_normalize.pkl", eval_env)

#  do not update them at test time
eval_env.training = False
# reward normalization is not needed at test time
eval_env.norm_reward = False

# Load the agent
model = A2C.load(model_name)

mean_reward, std_reward = evaluate_policy(model, eval_env)

print(f"Mean reward = {mean_reward:.2f} +/- {std_reward:.2f}")

# 8
package_to_hub(
    model=model,
    model_name=f"a2c-{env_id}",
    model_architecture="A2C",
    env_id=env_id,
    eval_env=eval_env,
    repo_id=f"zhoushch/unit6-a2c-{env_id}", # TODO: Change the username
    commit_message="Initial commit",
)
# Out:
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Mean reward = -45.00 +/- 15.00
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to 1min.
# This is a work in progress: if you encounter a bug, please open an issue.
# Saving video to /tmp/tmpu57hghpo/-step-0-to-step-1000.mp4
# Moviepy - Building video /tmp/tmpu57hghpo/-step-0-to-step-1000.mp4.
# Moviepy - Writing video /tmp/tmpu57hghpo/-step-0-to-step-1000.mp4
# Moviepy - Done !
# Moviepy - video ready /tmp/tmpu57hghpo/-step-0-to-step-1000.mp4
# ✘ 'DummyVecEnv' object has no attribute 'video_recorder'
# ✘ We are unable to generate a replay of your agent, the package_to_hub
# process continues
# ✘ Please open an issue at
# https://github.com/huggingface/huggingface_sb3/issues
# ℹ Pushing repo zhoushch/unit6-a2c-PandaPickAndPlace-v3 to the Hugging
# Face Hub
# a2c-PandaPickAndPlace-v3.zip:   0%|          | 0.00/130k [00:00<?, ?B/s]
# pytorch_variables.pth:   0%|          | 0.00/864 [00:00<?, ?B/s]
# policy.optimizer.pth:   0%|          | 0.00/55.4k [00:00<?, ?B/s]
# policy.pth:   0%|          | 0.00/53.4k [00:00<?, ?B/s]
# Upload 5 LFS files:   0%|          | 0/5 [00:00<?, ?it/s]
# vec_normalize.pkl:   0%|          | 0.00/3.04k [00:00<?, ?B/s]
# ℹ Your model is pushed to the Hub. You can view your model here:
# https://huggingface.co/zhoushch/unit6-a2c-PandaPickAndPlace-v3/tree/main/
# CommitInfo(commit_url='https://huggingface.co/zhoushch/unit6-a2c-PandaPickAndPlace-v3/commit/9097b295f60c0714abf80963e145e8d9b7486183', commit_message='Initial commit', commit_description='', oid='9097b295f60c0714abf80963e145e8d9b7486183', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# See you on Unit 7! 🔥
# ## Keep learning, stay awesome 🤗
