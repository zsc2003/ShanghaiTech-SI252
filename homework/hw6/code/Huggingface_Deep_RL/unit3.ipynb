# %% [markdown]
# # Unit 3: Deep Q-Learning with Atari Games 👾 using RL Baselines3 Zoo
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit4/thumbnail.jpg" alt="Unit 3 Thumbnail">
#
# In this notebook, **you'll train a Deep Q-Learning agent** playing Space Invaders using [RL Baselines3 Zoo](https://github.com/DLR-RM/rl-baselines3-zoo), a training framework based on [Stable-Baselines3](https://stable-baselines3.readthedocs.io/en/master/) that provides scripts for training, evaluating agents, tuning hyperparameters, plotting results and recording videos.
#
# We're using the [RL-Baselines-3 Zoo integration, a vanilla version of Deep Q-Learning](https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html) with no extensions such as Double-DQN, Dueling-DQN, and Prioritized Experience Replay.
#
# ⬇️ Here is an example of what **you will achieve** ⬇️

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/ThomasSimonini/ppo-SpaceInvadersNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>
# Out:
# <video controls autoplay><source src="https://huggingface.co/ThomasSimonini/ppo-SpaceInvadersNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>

# %% [markdown]
# ### 🎮 Environments:
#
# - [SpacesInvadersNoFrameskip-v4](https://gymnasium.farama.org/environments/atari/space_invaders/)
#
# You can see the difference between Space Invaders versions here 👉 https://gymnasium.farama.org/environments/atari/space_invaders/#variants
#
# ### 📚 RL-Library:
#
# - [RL-Baselines3-Zoo](https://github.com/DLR-RM/rl-baselines3-zoo)

# %% [markdown]
# ## Objectives of this notebook 🏆
# At the end of the notebook, you will:
# - Be able to understand deeper **how RL Baselines3 Zoo works**.
# - Be able to **push your trained agent and the code to the Hub** with a nice video replay and an evaluation score 🔥.

# %% [markdown]
# ## This notebook is from Deep Reinforcement Learning Course
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/deep-rl-course-illustration.jpg" alt="Deep RL Course illustration"/>

# %% [markdown]
# In this free course, you will:
#
# - 📖 Study Deep Reinforcement Learning in **theory and practice**.
# - 🧑‍💻 Learn to **use famous Deep RL libraries** such as Stable Baselines3, RL Baselines3 Zoo, CleanRL and Sample Factory 2.0.
# - 🤖 Train **agents in unique environments**
#
# And more check 📚 the syllabus 👉 https://simoninithomas.github.io/deep-rl-course
#
# Don’t forget to **<a href="http://eepurl.com/ic5ZUD">sign up to the course</a>** (we are collecting your email to be able to **send you the links when each Unit is published and give you information about the challenges and updates).**
#
#
# The best way to keep in touch is to join our discord server to exchange with the community and with us 👉🏻 https://discord.gg/ydHrjt3WP5

# %% [markdown]
# ## Prerequisites 🏗️
# Before diving into the notebook, you need to:
#
# 🔲 📚 **[Study Deep Q-Learning by reading Unit 3](https://huggingface.co/deep-rl-course/unit3/introduction)**  🤗

# %% [markdown]
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the Github Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# # Let's train a Deep Q-Learning agent playing Atari' Space Invaders 👾 and upload it to the Hub.
#
# We strongly recommend students **to use Google Colab for the hands-on exercises instead of running them on their personal computers**.
#
# By using Google Colab, **you can focus on learning and experimenting without worrying about the technical aspects of setting up your environments**.
#
# To validate this hands-on for the certification process, you need to push your trained model to the Hub and **get a result of >= 200**.
#
# To find your result, go to the leaderboard and find your model, **the result = mean_reward - std of reward**
#
# For more information about the certification process, check this section 👉 https://huggingface.co/deep-rl-course/en/unit0/introduction#certification-process

# %% [markdown]
# ## An advice 💡
# It's better to run this colab in a copy on your Google Drive, so that **if it timeouts** you still have the saved notebook on your Google Drive and do not need to fill everything from scratch.
#
# To do that you can either do `Ctrl + S` or `File > Save a copy in Google Drive.`
#
# Also, we're going to **train it for 90 minutes with 1M timesteps**. By typing `!nvidia-smi` will tell you what GPU you're using.
#
# And if you want to train more such 10 million steps, this will take about 9 hours, potentially resulting in Colab timing out. In that case, I recommend running this on your local computer (or somewhere else). Just click on: `File>Download`.

# %% [markdown]
# ## Set the GPU 💪
# - To **accelerate the agent's training, we'll use a GPU**. To do that, go to `Runtime > Change Runtime type`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step1.jpg" alt="GPU Step 1">

# %% [markdown]
# - `Hardware Accelerator > GPU`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step2.jpg" alt="GPU Step 2">

# %% [markdown]
# # Install RL-Baselines3 Zoo and its dependencies 📚
#
# If you see `ERROR: pip's dependency resolver does not currently take into account all the packages that are installed.` **this is normal and it's not a critical error** there's a conflict of version. But the packages we need are installed.

# %%
# !pip install git+https://github.com/DLR-RM/rl-baselines3-zoo
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting git+https://github.com/DLR-RM/rl-baselines3-zoo
#   Cloning https://github.com/DLR-RM/rl-baselines3-zoo to /tmp/pip-req-build-c4axahgw
#   Running command git clone --filter=blob:none --quiet https://github.com/DLR-RM/rl-baselines3-zoo /tmp/pip-req-build-c4axahgw
#   Resolved https://github.com/DLR-RM/rl-baselines3-zoo to commit 577616cb9f13341579953cb0f6111e007acc0a1d
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# INFO: pip is looking at multiple versions of rl-zoo3 to determine which version is compatible with other requirements. This could take a while.
# ERROR: Ignored the following versions that require a different python version: 2.5.0 Requires-Python >=3.9; 2.5.0a0 Requires-Python >=3.9; 2.6.0 Requires-Python >=3.9; 2.6.0a0 Requires-Python >=3.9; 2.6.0a1 Requires-Python >=3.9; 2.6.0a2 Requires-Python >=3.9; 2.6.1a1 Requires-Python >=3.9
# ERROR: Could not find a version that satisfies the requirement sb3-contrib<3.0,>=2.6.1a1 (from rl-zoo3) (from versions: 0.9.0a2, 0.10.0a0, 0.10.0a1, 0.10.0, 0.11.0a0, 0.11.0a2, 0.11.0a3, 0.11.0a4, 0.11.0a5, 0.11.0, 0.11.1, 1.0rc1, 1.0, 1.1.0a6, 1.1.0a7, 1.1.0a11, 1.1.0, 1.2.0, 1.2.1a2, 1.3.0, 1.3.1a4, 1.3.1a7, 1.3.1a9, 1.4.0, 1.4.1a1, 1.5.0, 1.5.1a1, 1.5.1a5, 1.5.1a7, 1.5.1a8, 1.6.0, 1.6.1, 1.6.2, 1.7.0a0, 1.7.0a10, 1.7.0a11, 1.7.0a12, 1.7.0, 1.8.0a2, 1.8.0a8, 1.8.0a9, 1.8.0a10, 1.8.0a13, 1.8.0a14, 1.8.0, 2.0.0a1, 2.0.0a2, 2.0.0a4, 2.0.0a9, 2.0.0a13, 2.0.0, 2.1.0, 2.2.0a8, 2.2.0a9, 2.2.0a11, 2.2.0, 2.2.1, 2.3.0a1, 2.3.0a4, 2.3.0, 2.4.0a4, 2.4.0a10, 2.4.0a11, 2.4.0)
# ERROR: No matching distribution found for sb3-contrib<3.0,>=2.6.1a1

# %%
# !apt-get install swig cmake ffmpeg
# Out:
# E: 无法打开锁文件 /var/lib/dpkg/lock-frontend - open (13: 权限不够)
# E: 无法获取 dpkg 前端锁 (/var/lib/dpkg/lock-frontend)，请查看您是否正以 root 用户运行？

# %% [markdown]
# To be able to use Atari games in Gymnasium we need to install atari package. And accept-rom-license to download the rom files (games files).

# %%
# !pip install gymnasium[atari]
# !pip install gymnasium[accept-rom-license]
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: gymnasium[atari] in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (1.1.1)
# Requirement already satisfied: numpy>=1.21.0 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from gymnasium[atari]) (1.24.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from gymnasium[atari]) (3.1.1)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from gymnasium[atari]) (8.5.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/cellverse/.local/lib/python3.8/site-packages (from gymnasium[atari]) (4.9.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from gymnasium[atari]) (0.0.4)
# Collecting ale_py>=0.9 (from gymnasium[atari])
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/9e/4a/8398d145fb7c337a318c89e6f3ab05bfd99ab1f7116c54dd56f52a78b70f/ale_py-0.10.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 20.6 MB/s eta 0:00:00
# Requirement already satisfied: importlib-resources in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from ale_py>=0.9->gymnasium[atari]) (6.4.5)
# Requirement already satisfied: zipp>=3.20 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from importlib-metadata>=4.8.0->gymnasium[atari]) (3.21.0)
# Installing collected packages: ale_py
# Successfully installed ale_py-0.10.1
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: gymnasium[accept-rom-license] in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (1.1.1)
# WARNING: gymnasium 1.1.1 does not provide the extra 'accept-rom-license'
# Requirement already satisfied: numpy>=1.21.0 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from gymnasium[accept-rom-license]) (1.24.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from gymnasium[accept-rom-license]) (3.1.1)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from gymnasium[accept-rom-license]) (8.5.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/cellverse/.local/lib/python3.8/site-packages (from gymnasium[accept-rom-license]) (4.9.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from gymnasium[accept-rom-license]) (0.0.4)
# Requirement already satisfied: zipp>=3.20 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from importlib-metadata>=4.8.0->gymnasium[accept-rom-license]) (3.21.0)

# %% [markdown]
# ## Create a virtual display 🔽
#
# During the notebook, we'll need to generate a replay video. To do so, with colab, **we need to have a virtual screen to be able to render the environment** (and thus record the frames).
#
# Hence the following cell will install the librairies and create and run a virtual screen 🖥

# %%
# %%capture
# !apt install python-opengl
# !apt install xvfb
# !pip3 install pyvirtualdisplay

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %% [markdown]
# ## Train our Deep Q-Learning Agent to Play Space Invaders 👾
#
# To train an agent with RL-Baselines3-Zoo, we just need to do two things:
#
# 1. Create a hyperparameter config file that will contain our training hyperparameters called `dqn.yml`.
#
# This is a template example:
#
# ```
# SpaceInvadersNoFrameskip-v4:
#   env_wrapper:
#     - stable_baselines3.common.atari_wrappers.AtariWrapper
#   frame_stack: 4
#   policy: 'CnnPolicy'
#   n_timesteps: !!float 1e6
#   buffer_size: 100000
#   learning_rate: !!float 1e-4
#   batch_size: 32
#   learning_starts: 100000
#   target_update_interval: 1000
#   train_freq: 4
#   gradient_steps: 1
#   exploration_fraction: 0.1
#   exploration_final_eps: 0.01
#   # If True, you need to deactivate handle_timeout_termination
#   # in the replay_buffer_kwargs
#   optimize_memory_usage: False
# ```

# %% [markdown]
# Here we see that:
# - We use the `Atari Wrapper` that preprocess the input (Frame reduction ,grayscale, stack 4 frames)
# - We use `CnnPolicy`, since we use Convolutional layers to process the frames
# - We train it for 10 million `n_timesteps`
# - Memory (Experience Replay) size is 100000, aka the amount of experience steps you saved to train again your agent with.
#
# 💡 My advice is to **reduce the training timesteps to 1M,** which will take about 90 minutes on a P100. `!nvidia-smi` will tell you what GPU you're using. At 10 million steps, this will take about 9 hours, which could likely result in Colab timing out. I recommend running this on your local computer (or somewhere else). Just click on: `File>Download`.

# %% [markdown]
# In terms of hyperparameters optimization, my advice is to focus on these 3 hyperparameters:
# - `learning_rate`
# - `buffer_size (Experience Memory size)`
# - `batch_size`
#
# As a good practice, you need to **check the documentation to understand what each hyperparameters does**: https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html#parameters

# %% [markdown]
# 2. We start the training and save the models on `logs` folder 📁
#
# - Define the algorithm after `--algo`, where we save the model after `-f` and where the hyperparameter config is after `-c`.

# %%
# !pip install rl_zoo3
# !pip install opencv-python
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: rl_zoo3 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (2.4.0)
# Requirement already satisfied: sb3-contrib<3.0,>=2.4.0 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from rl_zoo3) (2.4.0)
# Requirement already satisfied: gymnasium<1.1.0,>=0.29.1 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from rl_zoo3) (1.0.0)
# Requirement already satisfied: huggingface-sb3<4.0,>=3.0 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from rl_zoo3) (3.0)
# Requirement already satisfied: tqdm in /home/cellverse/.local/lib/python3.8/site-packages (from rl_zoo3) (4.66.1)
# Requirement already satisfied: rich in /home/cellverse/.local/lib/python3.8/site-packages (from rl_zoo3) (13.7.1)
# Requirement already satisfied: optuna>=3.0 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from rl_zoo3) (4.3.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from rl_zoo3) (6.0)
# Requirement already satisfied: pytablewriter~=1.2 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from rl_zoo3) (1.2.0)
# Requirement already satisfied: shimmy~=2.0 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from rl_zoo3) (2.0.0)
# Requirement already satisfied: numpy>=1.21.0 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from gymnasium<1.1.0,>=0.29.1->rl_zoo3) (1.24.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from gymnasium<1.1.0,>=0.29.1->rl_zoo3) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/cellverse/.local/lib/python3.8/site-packages (from gymnasium<1.1.0,>=0.29.1->rl_zoo3) (4.9.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from gymnasium<1.1.0,>=0.29.1->rl_zoo3) (0.0.4)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from gymnasium<1.1.0,>=0.29.1->rl_zoo3) (8.5.0)
# Requirement already satisfied: huggingface-hub~=0.8 in /home/cellverse/.local/lib/python3.8/site-packages (from huggingface-sb3<4.0,>=3.0->rl_zoo3) (0.20.2)
# Requirement already satisfied: wasabi in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from huggingface-sb3<4.0,>=3.0->rl_zoo3) (1.1.3)
# Requirement already satisfied: alembic>=1.5.0 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from optuna>=3.0->rl_zoo3) (1.14.1)
# Requirement already satisfied: colorlog in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from optuna>=3.0->rl_zoo3) (6.9.0)
# Requirement already satisfied: packaging>=20.0 in /home/cellverse/.local/lib/python3.8/site-packages (from optuna>=3.0->rl_zoo3) (23.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from optuna>=3.0->rl_zoo3) (2.0.41)
# Requirement already satisfied: setuptools>=38.3.0 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from pytablewriter~=1.2->rl_zoo3) (75.3.0)
# Requirement already satisfied: DataProperty<2,>=1.0.1 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from pytablewriter~=1.2->rl_zoo3) (1.0.1)
# Requirement already satisfied: mbstrdecoder<2,>=1.0.0 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from pytablewriter~=1.2->rl_zoo3) (1.1.3)
# Requirement already satisfied: pathvalidate<4,>=2.3.0 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from pytablewriter~=1.2->rl_zoo3) (3.2.1)
# Requirement already satisfied: tabledata<2,>=1.3.1 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from pytablewriter~=1.2->rl_zoo3) (1.3.3)
# Requirement already satisfied: tcolorpy<1,>=0.0.5 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from pytablewriter~=1.2->rl_zoo3) (0.1.6)
# Requirement already satisfied: typepy<2,>=1.3.2 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3) (1.3.2)
# Requirement already satisfied: stable-baselines3<3.0,>=2.4.0 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from sb3-contrib<3.0,>=2.4.0->rl_zoo3) (2.4.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/cellverse/.local/lib/python3.8/site-packages (from rich->rl_zoo3) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/cellverse/.local/lib/python3.8/site-packages (from rich->rl_zoo3) (2.18.0)
# Requirement already satisfied: Mako in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from alembic>=1.5.0->optuna>=3.0->rl_zoo3) (1.3.10)
# Requirement already satisfied: importlib-resources in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from alembic>=1.5.0->optuna>=3.0->rl_zoo3) (6.4.5)
# Requirement already satisfied: filelock in /home/cellverse/.local/lib/python3.8/site-packages (from huggingface-hub~=0.8->huggingface-sb3<4.0,>=3.0->rl_zoo3) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/cellverse/.local/lib/python3.8/site-packages (from huggingface-hub~=0.8->huggingface-sb3<4.0,>=3.0->rl_zoo3) (2023.12.2)
# Requirement already satisfied: requests in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from huggingface-hub~=0.8->huggingface-sb3<4.0,>=3.0->rl_zoo3) (2.32.3)
# Requirement already satisfied: zipp>=3.20 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from importlib-metadata>=4.8.0->gymnasium<1.1.0,>=0.29.1->rl_zoo3) (3.21.0)
# Requirement already satisfied: mdurl~=0.1 in /home/cellverse/.local/lib/python3.8/site-packages (from markdown-it-py>=2.2.0->rich->rl_zoo3) (0.1.2)
# Requirement already satisfied: chardet<6,>=3.0.4 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from mbstrdecoder<2,>=1.0.0->pytablewriter~=1.2->rl_zoo3) (5.2.0)
# Requirement already satisfied: greenlet>=1 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from sqlalchemy>=1.4.2->optuna>=3.0->rl_zoo3) (3.1.1)
# Requirement already satisfied: torch>=1.13 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (2.4.1+cu118)
# Requirement already satisfied: pandas in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (2.0.3)
# Requirement already satisfied: matplotlib in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (3.7.5)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3) (2.9.0)
# Requirement already satisfied: pytz>=2018.9 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from python-dateutil<3.0.0,>=2.8.0->typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3) (1.16.0)
# Requirement already satisfied: sympy in /home/cellverse/.local/lib/python3.8/site-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (1.12)
# Requirement already satisfied: networkx in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (3.0)
# Requirement already satisfied: jinja2 in /home/cellverse/.local/lib/python3.8/site-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.8.89 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (11.8.89)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.8.89 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (11.8.89)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.8.87 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (11.8.87)
# Requirement already satisfied: nvidia-cudnn-cu11==9.1.0.70 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu11==11.11.3.6 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (11.11.3.6)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.3.0.86 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (10.3.0.86)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.1.48 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (11.4.1.48)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.5.86 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (11.7.5.86)
# Requirement already satisfied: nvidia-nccl-cu11==2.20.5 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu11==11.8.86 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (11.8.86)
# Requirement already satisfied: triton==3.0.0 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from torch>=1.13->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (3.0.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /home/cellverse/.local/lib/python3.8/site-packages (from Mako->alembic>=1.5.0->optuna>=3.0->rl_zoo3) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from matplotlib->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from matplotlib->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from matplotlib->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from matplotlib->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from matplotlib->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from matplotlib->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (3.1.4)
# Requirement already satisfied: tzdata>=2022.1 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from pandas->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from requests->huggingface-hub~=0.8->huggingface-sb3<4.0,>=3.0->rl_zoo3) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from requests->huggingface-hub~=0.8->huggingface-sb3<4.0,>=3.0->rl_zoo3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from requests->huggingface-hub~=0.8->huggingface-sb3<4.0,>=3.0->rl_zoo3) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from requests->huggingface-hub~=0.8->huggingface-sb3<4.0,>=3.0->rl_zoo3) (2025.4.26)
# Requirement already satisfied: mpmath>=0.19 in /home/cellverse/.local/lib/python3.8/site-packages (from sympy->torch>=1.13->stable-baselines3<3.0,>=2.4.0->sb3-contrib<3.0,>=2.4.0->rl_zoo3) (1.3.0)
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: opencv-python in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.17.0 in /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages (from opencv-python) (1.24.4)

# %%
# !python -m rl_zoo3.train --algo dqn  --env SpaceInvadersNoFrameskip-v4 -f logs/ -c dqn.yml
# Out:
# ========== SpaceInvadersNoFrameskip-v4 ==========
# Seed: 188603973
# Loading hyperparameters from: dqn.yml
# Default hyperparameters for environment (ones being tuned will be overridden):
# OrderedDict([('batch_size', 32),
#              ('buffer_size', 100000),
#              ('env_wrapper',
#               ['stable_baselines3.common.atari_wrappers.AtariWrapper']),
#              ('exploration_final_eps', 0.01),
#              ('exploration_fraction', 0.1),
#              ('frame_stack', 4),
#              ('gradient_steps', 1),
#              ('learning_rate', 0.0001),
#              ('learning_starts', 100000),
#              ('n_timesteps', 1000000.0),
#              ('optimize_memory_usage', False),
#              ('policy', 'CnnPolicy'),
#              ('target_update_interval', 1000),
#              ('train_freq', 4)])
# Using 1 environments
# Creating test environment
# A.L.E: Arcade Learning Environment (version 0.10.1+unknown)
# [Powered by Stella]
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Using cuda device
# Log path: logs//dqn/SpaceInvadersNoFrameskip-v4_3
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.77e+03 |
# |    ep_rew_mean      | 285      |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1879     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1017     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.21e+03 |
# |    ep_rew_mean      | 515      |
# |    exploration_rate | 0.98     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 2034     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2023     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.91e+03 |
# |    ep_rew_mean      | 342      |
# |    exploration_rate | 0.972    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 2072     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2863     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.63e+03 |
# |    ep_rew_mean      | 286      |
# |    exploration_rate | 0.967    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 2084     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3380     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.52e+03 |
# |    ep_rew_mean      | 263      |
# |    exploration_rate | 0.96     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 2094     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3998     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.37e+03 |
# |    ep_rew_mean      | 230      |
# |    exploration_rate | 0.954    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 2097     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4644     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.37e+03 |
# |    ep_rew_mean      | 236      |
# |    exploration_rate | 0.946    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 2103     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 5414     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.31e+03 |
# |    ep_rew_mean      | 223      |
# |    exploration_rate | 0.937    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 2105     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 6325     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.42e+03 |
# |    ep_rew_mean      | 235      |
# |    exploration_rate | 0.93     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 2101     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 7116     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.36e+03 |
# |    ep_rew_mean      | 222      |
# |    exploration_rate | 0.924    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 2101     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 7708     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.29e+03 |
# |    ep_rew_mean      | 208      |
# |    exploration_rate | 0.918    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 2100     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 8240     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.22e+03 |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.914    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 2098     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 8701     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.19e+03 |
# |    ep_rew_mean      | 189      |
# |    exploration_rate | 0.907    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 2097     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 9369     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.3e+03  |
# |    ep_rew_mean      | 202      |
# |    exploration_rate | 0.896    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 2104     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 10537    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.32e+03 |
# |    ep_rew_mean      | 204      |
# |    exploration_rate | 0.888    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 2103     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 11349    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.26e+03 |
# |    ep_rew_mean      | 195      |
# |    exploration_rate | 0.884    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 2102     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 11728    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 188      |
# |    exploration_rate | 0.879    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 2100     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 12201    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.19e+03 |
# |    ep_rew_mean      | 183      |
# |    exploration_rate | 0.873    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 2100     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 12874    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.15e+03 |
# |    ep_rew_mean      | 178      |
# |    exploration_rate | 0.867    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 2099     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 13406    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 176      |
# |    exploration_rate | 0.86     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 2099     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 14135    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.22e+03 |
# |    ep_rew_mean      | 190      |
# |    exploration_rate | 0.85     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 2100     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 15202    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.2e+03  |
# |    ep_rew_mean      | 187      |
# |    exploration_rate | 0.844    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 2100     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 15736    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.17e+03 |
# |    ep_rew_mean      | 184      |
# |    exploration_rate | 0.833    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 2102     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 16826    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.19e+03 |
# |    ep_rew_mean      | 195      |
# |    exploration_rate | 0.83     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 2099     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 17152    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.19e+03 |
# |    ep_rew_mean      | 193      |
# |    exploration_rate | 0.822    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 2099     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 17988    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.19e+03 |
# |    ep_rew_mean      | 189      |
# |    exploration_rate | 0.816    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 2099     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 18572    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 189      |
# |    exploration_rate | 0.807    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 2096     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 19468    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.19e+03 |
# |    ep_rew_mean      | 185      |
# |    exploration_rate | 0.802    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 2095     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 20005    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.19e+03 |
# |    ep_rew_mean      | 186      |
# |    exploration_rate | 0.795    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 2096     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 20725    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.19e+03 |
# |    ep_rew_mean      | 185      |
# |    exploration_rate | 0.788    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 2094     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 21425    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.19e+03 |
# |    ep_rew_mean      | 184      |
# |    exploration_rate | 0.781    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 2094     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 22112    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.18e+03 |
# |    ep_rew_mean      | 181      |
# |    exploration_rate | 0.776    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 2094     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 22643    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 176      |
# |    exploration_rate | 0.772    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 2092     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 23038    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 174      |
# |    exploration_rate | 0.766    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 2091     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 23645    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 173      |
# |    exploration_rate | 0.76     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 2091     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 24220    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 168      |
# |    exploration_rate | 0.754    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 2089     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 24801    |
# ----------------------------------
# Eval num_timesteps=25000, episode_reward=170.00 +/- 67.45
# Episode length: 2024.20 +/- 796.44
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.02e+03 |
# |    mean_reward      | 170      |
# | rollout/            |          |
# |    exploration_rate | 0.753    |
# | time/               |          |
# |    total_timesteps  | 25000    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 166      |
# |    exploration_rate | 0.749    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 1813     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 25372    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 164      |
# |    exploration_rate | 0.744    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 1817     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 25859    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 161      |
# |    exploration_rate | 0.739    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 1820     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 26398    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.729    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 1828     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 27363    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 163      |
# |    exploration_rate | 0.722    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 1833     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 28056    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 161      |
# |    exploration_rate | 0.718    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 1836     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 28509    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.711    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 1840     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 29194    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.705    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 1844     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 29763    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.701    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 1847     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 30236    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.694    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 1851     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 30940    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.687    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 1855     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 31585    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.679    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 1860     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 32454    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.671    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 1864     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 33196    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.664    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 1868     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 33959    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.659    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 1870     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 34468    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.653    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 1872     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 35030    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.645    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 1877     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 35839    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.638    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 1880     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 36582    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.633    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 1882     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 37080    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.629    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 1884     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 37505    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.621    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 1887     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 38305    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.613    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 1890     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 39049    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.607    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 1893     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 39687    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.603    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 1894     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 40130    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.597    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 1896     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 40670    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.592    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 1898     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 41250    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.586    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 1899     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 41808    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.58     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 1902     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 42462    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.573    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 1904     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 43133    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.565    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 1907     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 43985    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.557    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 1909     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 44728    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.55     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 1912     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 45459    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.542    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 1915     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 46241    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.536    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 1917     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 46831    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.529    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 1919     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 47590    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.522    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 1921     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 48289    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.515    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 1923     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 48964    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.512    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 1923     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 49321    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.508    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 1923     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 49650    |
# ----------------------------------
# Eval num_timesteps=50000, episode_reward=124.00 +/- 56.52
# Episode length: 1816.20 +/- 437.15
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 1.82e+03 |
# |    mean_reward      | 124      |
# | rollout/            |          |
# |    exploration_rate | 0.505    |
# | time/               |          |
# |    total_timesteps  | 50000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 142      |
# |    exploration_rate | 0.503    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 1799     |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 50199    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.497    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 1801     |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 50772    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.492    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 1803     |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 51341    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.98e+03 |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.484    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 1807     |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 52071    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.476    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 1811     |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 52902    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.472    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 1812     |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 53299    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.464    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 1815     |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 54145    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.454    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 1820     |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 55183    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.447    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 1823     |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 55872    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.441    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 1825     |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 56473    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.433    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 1828     |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 57297    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.429    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 1829     |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 57644    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.421    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 1832     |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 58457    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.408    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 1837     |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 59831    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.403    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 1839     |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 60306    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.395    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 1842     |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 61135    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.388    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 1845     |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 61780    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.379    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 1848     |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 62714    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.372    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 1849     |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 63405    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.363    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 1852     |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 64337    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.356    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 1854     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 65050    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.347    |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 1856     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 65910    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.343    |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 1857     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 66316    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 133      |
# |    exploration_rate | 0.339    |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 1859     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 66809    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 132      |
# |    exploration_rate | 0.334    |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 1860     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 67296    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 133      |
# |    exploration_rate | 0.327    |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 1862     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 67930    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.321    |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 1863     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 68621    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.313    |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 1865     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 69384    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.308    |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 1867     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 69929    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.302    |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 1868     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 70488    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.297    |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 1869     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 70985    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.292    |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 1870     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 71549    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.285    |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 1872     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 72271    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.28     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 1873     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 72777    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.272    |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 1874     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 73494    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.267    |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 1875     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 74009    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.26     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 1877     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 74769    |
# ----------------------------------
# Eval num_timesteps=75000, episode_reward=207.00 +/- 123.03
# Episode length: 1890.20 +/- 314.68
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 1.89e+03 |
# |    mean_reward      | 207      |
# | rollout/            |          |
# |    exploration_rate | 0.258    |
# | time/               |          |
# |    total_timesteps  | 75000    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 141      |
# |    exploration_rate | 0.253    |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 1773     |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 75460    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.246    |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 1776     |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 76163    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 141      |
# |    exploration_rate | 0.24     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 1777     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 76718    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 142      |
# |    exploration_rate | 0.233    |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 1779     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 77489    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 142      |
# |    exploration_rate | 0.228    |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 1781     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 78011    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 142      |
# |    exploration_rate | 0.222    |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 1783     |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 78622    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 142      |
# |    exploration_rate | 0.217    |
# ...
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0107   |
# |    n_updates        | 213546   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4e+03    |
# |    ep_rew_mean      | 583      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3812     |
# |    fps              | 494      |
# |    time_elapsed     | 1932     |
# |    total_timesteps  | 956493   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0115   |
# |    n_updates        | 214123   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.01e+03 |
# |    ep_rew_mean      | 584      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3816     |
# |    fps              | 494      |
# |    time_elapsed     | 1935     |
# |    total_timesteps  | 957919   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0191   |
# |    n_updates        | 214479   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.02e+03 |
# |    ep_rew_mean      | 582      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3820     |
# |    fps              | 494      |
# |    time_elapsed     | 1939     |
# |    total_timesteps  | 959818   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0103   |
# |    n_updates        | 214954   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.04e+03 |
# |    ep_rew_mean      | 591      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3824     |
# |    fps              | 494      |
# |    time_elapsed     | 1941     |
# |    total_timesteps  | 960984   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0254   |
# |    n_updates        | 215245   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.03e+03 |
# |    ep_rew_mean      | 589      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3828     |
# |    fps              | 494      |
# |    time_elapsed     | 1943     |
# |    total_timesteps  | 961679   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0938   |
# |    n_updates        | 215419   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4e+03    |
# |    ep_rew_mean      | 583      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3832     |
# |    fps              | 494      |
# |    time_elapsed     | 1947     |
# |    total_timesteps  | 963872   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0244   |
# |    n_updates        | 215967   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.01e+03 |
# |    ep_rew_mean      | 584      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3836     |
# |    fps              | 494      |
# |    time_elapsed     | 1950     |
# |    total_timesteps  | 965166   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0231   |
# |    n_updates        | 216291   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4e+03    |
# |    ep_rew_mean      | 582      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3840     |
# |    fps              | 494      |
# |    time_elapsed     | 1953     |
# |    total_timesteps  | 967096   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0293   |
# |    n_updates        | 216773   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.01e+03 |
# |    ep_rew_mean      | 583      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3844     |
# |    fps              | 494      |
# |    time_elapsed     | 1955     |
# |    total_timesteps  | 968110   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0551   |
# |    n_updates        | 217027   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.95e+03 |
# |    ep_rew_mean      | 569      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3848     |
# |    fps              | 494      |
# |    time_elapsed     | 1957     |
# |    total_timesteps  | 969202   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0154   |
# |    n_updates        | 217300   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.89e+03 |
# |    ep_rew_mean      | 560      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3852     |
# |    fps              | 495      |
# |    time_elapsed     | 1962     |
# |    total_timesteps  | 971370   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0241   |
# |    n_updates        | 217842   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.91e+03 |
# |    ep_rew_mean      | 562      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3856     |
# |    fps              | 495      |
# |    time_elapsed     | 1965     |
# |    total_timesteps  | 972866   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0109   |
# |    n_updates        | 218216   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.91e+03 |
# |    ep_rew_mean      | 561      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3860     |
# |    fps              | 495      |
# |    time_elapsed     | 1967     |
# |    total_timesteps  | 974006   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0278   |
# |    n_updates        | 218501   |
# ----------------------------------
# Eval num_timesteps=975000, episode_reward=656.00 +/- 250.35
# Episode length: 4538.40 +/- 1602.98
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 4.54e+03 |
# |    mean_reward      | 656      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 975000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0126   |
# |    n_updates        | 218749   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.89e+03 |
# |    ep_rew_mean      | 559      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3864     |
# |    fps              | 493      |
# |    time_elapsed     | 1975     |
# |    total_timesteps  | 975027   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0518   |
# |    n_updates        | 218756   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.88e+03 |
# |    ep_rew_mean      | 559      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3868     |
# |    fps              | 493      |
# |    time_elapsed     | 1978     |
# |    total_timesteps  | 976902   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00703  |
# |    n_updates        | 219225   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.84e+03 |
# |    ep_rew_mean      | 550      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3872     |
# |    fps              | 493      |
# |    time_elapsed     | 1981     |
# |    total_timesteps  | 978093   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0192   |
# |    n_updates        | 219523   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.83e+03 |
# |    ep_rew_mean      | 548      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3876     |
# |    fps              | 493      |
# |    time_elapsed     | 1985     |
# |    total_timesteps  | 980204   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0166   |
# |    n_updates        | 220050   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.84e+03 |
# |    ep_rew_mean      | 549      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3880     |
# |    fps              | 493      |
# |    time_elapsed     | 1987     |
# |    total_timesteps  | 981510   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0159   |
# |    n_updates        | 220377   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.83e+03 |
# |    ep_rew_mean      | 542      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3884     |
# |    fps              | 493      |
# |    time_elapsed     | 1990     |
# |    total_timesteps  | 983076   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0252   |
# |    n_updates        | 220768   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.84e+03 |
# |    ep_rew_mean      | 542      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3888     |
# |    fps              | 493      |
# |    time_elapsed     | 1993     |
# |    total_timesteps  | 984217   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0158   |
# |    n_updates        | 221054   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.84e+03 |
# |    ep_rew_mean      | 541      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3892     |
# |    fps              | 493      |
# |    time_elapsed     | 1998     |
# |    total_timesteps  | 986815   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0195   |
# |    n_updates        | 221703   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.9e+03  |
# |    ep_rew_mean      | 549      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3896     |
# |    fps              | 493      |
# |    time_elapsed     | 2005     |
# |    total_timesteps  | 990721   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00906  |
# |    n_updates        | 222680   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.89e+03 |
# |    ep_rew_mean      | 548      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3900     |
# |    fps              | 493      |
# |    time_elapsed     | 2009     |
# |    total_timesteps  | 992742   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0213   |
# |    n_updates        | 223185   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.88e+03 |
# |    ep_rew_mean      | 547      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3904     |
# |    fps              | 493      |
# |    time_elapsed     | 2011     |
# |    total_timesteps  | 993645   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.039    |
# |    n_updates        | 223411   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.87e+03 |
# |    ep_rew_mean      | 541      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3908     |
# |    fps              | 493      |
# |    time_elapsed     | 2015     |
# |    total_timesteps  | 995410   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0419   |
# |    n_updates        | 223852   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.87e+03 |
# |    ep_rew_mean      | 543      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3912     |
# |    fps              | 494      |
# |    time_elapsed     | 2017     |
# |    total_timesteps  | 996560   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0178   |
# |    n_updates        | 224139   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.87e+03 |
# |    ep_rew_mean      | 546      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3916     |
# |    fps              | 494      |
# |    time_elapsed     | 2020     |
# |    total_timesteps  | 998296   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00959  |
# |    n_updates        | 224573   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.86e+03 |
# |    ep_rew_mean      | 544      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3920     |
# |    fps              | 494      |
# |    time_elapsed     | 2023     |
# |    total_timesteps  | 999814   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.033    |
# |    n_updates        | 224953   |
# ----------------------------------
# Eval num_timesteps=1000000, episode_reward=529.00 +/- 154.96
# Episode length: 3794.60 +/- 651.25
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.79e+03 |
# |    mean_reward      | 529      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 1000000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0556   |
# |    n_updates        | 224999   |
# ----------------------------------
# Saving to logs//dqn/SpaceInvadersNoFrameskip-v4_3

# %% [markdown]
# ## Let's evaluate our agent 👀
# - RL-Baselines3-Zoo provides `enjoy.py`, a python script to evaluate our agent. In most RL libraries, we call the evaluation script `enjoy.py`.
# - Let's evaluate it for 5000 timesteps 🔥

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps 5000  --folder logs/
# Out:
# Loading latest experiment, id=3
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_3/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.10.1+unknown)
# [Powered by Stella]
# Stacking 4 frames
# Atari Episode Score: 695.00
# Atari Episode Length 4303
# Atari Episode Score: 460.00
# Atari Episode Length 3831
# Atari Episode Score: 560.00
# Atari Episode Length 4550
# Atari Episode Score: 770.00
# Atari Episode Length 4923

# %% [markdown]
# ## Publish our trained model on the Hub 🚀
# Now that we saw we got good results after the training, we can publish our trained model on the hub 🤗 with one line of code.
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit3/space-invaders-model.gif" alt="Space Invaders model">

# %% [markdown]
# By using `rl_zoo3.push_to_hub` **you evaluate, record a replay, generate a model card of your agent and push it to the hub**.
#
# This way:
# - You can **showcase our work** 🔥
# - You can **visualize your agent playing** 👀
# - You can **share with the community an agent that others can use** 💾
# - You can **access a leaderboard 🏆 to see how well your agent is performing compared to your classmates** 👉  https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard

# %% [markdown]
# To be able to share your model with the community there are three more steps to follow:
#
# 1️⃣ (If it's not already done) create an account to HF ➡ https://huggingface.co/join
#
# 2️⃣ Sign in and then, you need to store your authentication token from the Hugging Face website.
# - Create a new token (https://huggingface.co/settings/tokens) **with write role**
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/create-token.jpg" alt="Create HF Token">

# %% [markdown]
# - Copy the token
# - Run the cell below and past the token

# %%
from huggingface_hub import login
login('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')

# !git config --global credential.helper store
# Out:
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /home/cellverse/.cache/huggingface/token
# Login successful

# %% [markdown]
# If you don't want to use a Google Colab or a Jupyter Notebook, you need to use this command instead: `huggingface-cli login`

# %% [markdown]
# 3️⃣ We're now ready to push our trained agent to the 🤗 Hub 🔥

# %% [markdown]
# Let's run push_to_hub.py file to upload our trained agent to the Hub.
#
# `--repo-name `: The name of the repo
#
# `-orga`: Your Hugging Face username
#
# `-f`: Where the trained model folder is (in our case `logs`)
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit3/select-id.png" alt="Select Id">

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name unit3-dqn-SpaceInvadersNoFrameskip-v4  -orga zhoushch  -f logs/
# Out:
# Loading latest experiment, id=3
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_3/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.10.1+unknown)
# [Powered by Stella]
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Uploading to zhoushch/unit3-dqn-SpaceInvadersNoFrameskip-v4, make sure to have the rights
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to some
# minutes if video generation is activated. This is a work in progress: if you
# encounter a bug, please open an issue.
# Fetching 1 files:   0%|                                   | 0/1 [00:00<?, ?it/s]
# .gitattributes: 100%|███████████████████████| 1.52k/1.52k [00:00<00:00, 190kB/s]
# Fetching 1 files: 100%|███████████████████████████| 1/1 [00:00<00:00,  1.13it/s]
# Saving model to: hub/unit3-dqn-SpaceInvadersNoFrameskip-v4/dqn-SpaceInvadersNoFrameskip-v4
# Saving video to /tmp/tmp3dzccn48/-step-0-to-step-1000.mp4
# Moviepy - Building video /tmp/tmp3dzccn48/-step-0-to-step-1000.mp4.
# Moviepy - Writing video /tmp/tmp3dzccn48/-step-0-to-step-1000.mp4
#
# Moviepy - Done !
# Moviepy - video ready /tmp/tmp3dzccn48/-step-0-to-step-1000.mp4
# ✘ 'DummyVecEnv' object has no attribute 'video_recorder'
# ✘ We are unable to generate a replay of your agent, the package_to_hub
# process continues
# ✘ Please open an issue at
# https://github.com/huggingface/huggingface_sb3/issues
# ℹ Pushing repo unit3-dqn-SpaceInvadersNoFrameskip-v4 to the Hugging
# Face Hub
# policy.optimizer.pth:   0%|                         | 0.00/13.5M [00:00<?, ?B/s]
# policy.pth:   0%|                                   | 0.00/13.5M [00:00<?, ?B/s]
#
# dqn-SpaceInvadersNoFrameskip-v4.zip:   0%|          | 0.00/27.2M [00:00<?, ?B/s]
#
#
# pytorch_variables.pth:   0%|                          | 0.00/864 [00:00<?, ?B/s]
#
#
#
# Upload 5 LFS files:   0%|                                 | 0/5 [00:00<?, ?it/s]
#
#
#
#
# train_eval_metrics.zip:   0%|                       | 0.00/36.3k [00:00<?, ?B/s]
#
#
#
#
# train_eval_metrics.zip:  45%|██████▊        | 16.4k/36.3k [00:00<00:00, 143kB/s]
# policy.pth:   0%|                           | 16.4k/13.5M [00:00<01:56, 116kB/s]
#
#
# pytorch_variables.pth: 100%|███████████████████| 864/864 [00:00<00:00, 6.52kB/s]
#
# policy.optimizer.pth:   0%|                | 16.4k/13.5M [00:00<02:39, 84.6kB/s]
#
# policy.optimizer.pth:  47%|███████▍        | 6.29M/13.5M [00:00<00:00, 26.7MB/s]
# policy.pth:  49%|████████████▊             | 6.68M/13.5M [00:00<00:00, 24.1MB/s]
# train_eval_metrics.zip: 100%|██████████████| 36.3k/36.3k [00:00<00:00, 43.9kB/s]
# pytorch_variables.pth: 100%|█████████████████████| 864/864 [00:01<00:00, 823B/s]
# policy.optimizer.pth:  74%|███████████▊    | 9.99M/13.5M [00:03<00:01, 2.15MB/s]
#
# dqn-SpaceInvadersNoFrameskip-v4.zip:  37%|▎| 10.1M/27.2M [00:04<00:09, 1.81MB/s]
#
# dqn-SpaceInvadersNoFrameskip-v4.zip:  43%|▍| 11.8M/27.2M [00:06<00:10, 1.40MB/s]
#
# dqn-SpaceInvadersNoFrameskip-v4.zip:  48%|▍| 13.2M/27.2M [00:08<00:12, 1.12MB/s]
# policy.pth:  78%|████████████████████▉      | 10.5M/13.5M [00:09<00:04, 712kB/s]
#
# policy.optimizer.pth:  89%|███████████████▏ | 12.1M/13.5M [00:10<00:01, 841kB/s]
# policy.pth: 100%|███████████████████████████| 13.5M/13.5M [00:15<00:00, 862kB/s]
# policy.optimizer.pth: 100%|█████████████████| 13.5M/13.5M [00:15<00:00, 860kB/s]
#
#
#
#
# Upload 5 LFS files:  20%|█████                    | 1/5 [00:16<01:05, 16.48s/it]
#
# dqn-SpaceInvadersNoFrameskip-v4.zip:  59%|█▏| 16.0M/27.2M [00:17<00:21, 511kB/s]
#
# dqn-SpaceInvadersNoFrameskip-v4.zip: 100%|█| 27.2M/27.2M [00:23<00:00, 1.16MB/s]
#
#
#
#
# Upload 5 LFS files: 100%|█████████████████████████| 5/5 [00:24<00:00,  4.80s/it]
# ℹ Your model is pushed to the hub. You can view your model here:
# https://huggingface.co/zhoushch/unit3-dqn-SpaceInvadersNoFrameskip-v4

# %% [markdown]
# ###.

# %% [markdown]
# Congrats 🥳 you've just trained and uploaded your first Deep Q-Learning agent using RL-Baselines-3 Zoo. The script above should have displayed a link to a model repository such as https://huggingface.co/ThomasSimonini/dqn-SpaceInvadersNoFrameskip-v4. When you go to this link, you can:
#
# - See a **video preview of your agent** at the right.
# - Click "Files and versions" to see all the files in the repository.
# - Click "Use in stable-baselines3" to get a code snippet that shows how to load the model.
# - A model card (`README.md` file) which gives a description of the model and the hyperparameters you used.
#
# Under the hood, the Hub uses git-based repositories (don't worry if you don't know what git is), which means you can update the model with new versions as you experiment and improve your agent.
#
# **Compare the results of your agents with your classmates** using the [leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) 🏆

# %% [markdown]
# ## Load a powerful trained model 🔥
# - The Stable-Baselines3 team uploaded **more than 150 trained Deep Reinforcement Learning agents on the Hub**.
#
# You can find them here: 👉 https://huggingface.co/sb3
#
# Some examples:
# - Asteroids: https://huggingface.co/sb3/dqn-AsteroidsNoFrameskip-v4
# - Beam Rider: https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4
# - Breakout: https://huggingface.co/sb3/dqn-BreakoutNoFrameskip-v4
# - Road Runner: https://huggingface.co/sb3/dqn-RoadRunnerNoFrameskip-v4
#
# Let's load an agent playing Beam Rider: https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>
# Out:
# <video controls autoplay><source src="https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>

# %% [markdown]
# 1. We download the model using `rl_zoo3.load_from_hub`, and place it in a new folder that we can call `rl_trained`

# %%
# Download model and save it into the logs/ folder
# !python -m rl_zoo3.load_from_hub --algo dqn --env BeamRiderNoFrameskip-v4 -orga sb3 -f logs/
# Out:
# Downloading from https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4
# dqn-BeamRiderNoFrameskip-v4.zip: 100%|█████| 27.2M/27.2M [00:01<00:00, 24.2MB/s]
# config.yml: 100%|███████████████████████████████| 548/548 [00:00<00:00, 132kB/s]
# No normalization file
# args.yml: 100%|█████████████████████████████████| 887/887 [00:00<00:00, 302kB/s]
# env_kwargs.yml: 100%|████████████████████████| 3.00/3.00 [00:00<00:00, 3.18kB/s]
# train_eval_metrics.zip: 100%|████████████████| 244k/244k [00:00<00:00, 47.8MB/s]
# Saving to logs/dqn/BeamRiderNoFrameskip-v4_1

# %% [markdown]
# 2. Let's evaluate if for 5000 timesteps

# %%
# !python -m rl_zoo3.enjoy --algo dqn --env BeamRiderNoFrameskip-v4 -n 5000  -f logs/ --no-render
# Out:
# Loading latest experiment, id=1
# Loading logs/dqn/BeamRiderNoFrameskip-v4_1/BeamRiderNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.10.1+unknown)
# [Powered by Stella]
# Stacking 4 frames
# /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages/stable_baselines3/common/save_util.py:167: UserWarning: Could not deserialize object exploration_schedule. Consider using `custom_objects` argument to replace this object.
# Exception: an integer is required (got type bytes)
#   warnings.warn(
# /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages/stable_baselines3/common/vec_env/patch_gym.py:95: UserWarning: You loaded a model that was trained using OpenAI Gym. We strongly recommend transitioning to Gymnasium by saving that model again.
#   warnings.warn(
# /home/cellverse/tools/miniconda3/envs/DRL/lib/python3.8/site-packages/stable_baselines3/common/base_class.py:772: UserWarning: You are probably loading a DQN model saved with SB3 < 2.4.0, we truncated the optimizer state so you can save the model again to avoid issues in the future (see https://github.com/DLR-RM/stable-baselines3/pull/1963 for more info). Original error: loaded state dict contains a parameter group that doesn't match the size of optimizer's group
# Note: the model should still work fine, this only a warning.
#   warnings.warn(
# Atari Episode Score: 3028.00
# Atari Episode Length 14816

# %% [markdown]
# Why not trying to train your own **Deep Q-Learning Agent playing BeamRiderNoFrameskip-v4? 🏆.**
#
# If you want to try, check https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4#hyperparameters **in the model card, you have the hyperparameters of the trained agent.**

# %% [markdown]
# But finding hyperparameters can be a daunting task. Fortunately, we'll see in the next Unit, how we can **use Optuna for optimizing the Hyperparameters 🔥.**

# %% [markdown]
# ## Some additional challenges 🏆
# The best way to learn **is to try things by your own**!
#
# In the [Leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) you will find your agents. Can you get to the top?
#
# Here's a list of environments you can try to train your agent with:
# - BeamRiderNoFrameskip-v4
# - BreakoutNoFrameskip-v4
# - EnduroNoFrameskip-v4
# - PongNoFrameskip-v4
#
# Also, **if you want to learn to implement Deep Q-Learning by yourself**, you definitely should look at CleanRL implementation: https://github.com/vwxyzjn/cleanrl/blob/master/cleanrl/dqn_atari.py
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit4/atari-envs.gif" alt="Environments"/>

# %% [markdown]
# ________________________________________________________________________
# Congrats on finishing this chapter!
#
# If you’re still feel confused with all these elements...it's totally normal! **This was the same for me and for all people who studied RL.**
#
# Take time to really **grasp the material before continuing and try the additional challenges**. It’s important to master these elements and having a solid foundations.
#
# In the next unit, **we’re going to learn about [Optuna](https://optuna.org/)**. One of the most critical task in Deep Reinforcement Learning is to find a good set of training hyperparameters. And Optuna is a library that helps you to automate the search.

# %% [markdown]
# ### This is a course built with you 👷🏿‍♀️
#
# Finally, we want to improve and update the course iteratively with your feedback. If you have some, please fill this form 👉 https://forms.gle/3HgA7bEHwAmmLfwh9
#
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the Github Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# See you on Bonus unit 2! 🔥

# %% [markdown]
# ### Keep Learning, Stay Awesome 🤗
